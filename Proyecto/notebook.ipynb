# %% [markdown]
# # Análisis de base de datos `olist`
#
# El objetivo de este análisis es crear un modelo de _machine learning_ que permita predecir el tiempo de entrega de órdenes en un _e-commerce_ brasileño llamado _Olist_.
#
# ## Importación de paquetes

# %%
import sqlite3
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from catboost import CatBoostRegressor
from geopy.distance import geodesic
from IPython.display import display
from lightgbm import LGBMRegressor
from scipy.stats import randint, uniform
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBRegressor

# %% [markdown]
# ## Obtención del _dataset_
#
# Con el código a continuación obtenemos el _dataset_ a partir de la base de datos _SQLite_ `olist.db`. El _dataset_ contiene información de órdenes, clientes, vendedores y productos, junto con datos geográficos asociados a códigos postales.
#
# Para más información sobre esta base de datos ver <https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce>.
#
# El archivo `olist.db` es una conversión de los archivos CSV originales a una base de datos SQLite. Esta conversión se realizó para facilitar la consulta y manipulación de los datos.

# %%
with sqlite3.connect("data/olist.db") as conn:
    query = """
    -- Obtenemos, según cada código postal, la latitud y longitud promedio.
    WITH geo_agg AS (
        SELECT 
            geolocation_zip_code_prefix,
            AVG(geolocation_lat) as lat,
            AVG(geolocation_lng) as lng
        FROM geolocation
        GROUP BY geolocation_zip_code_prefix
    ),
    -- Obtenemos, para cada orden, una agregación de todos los items incluidos en ella.
    item_agg AS (
        SELECT
            i.order_id,
            SUM(i.price) as total_price,
            SUM(i.freight_value) as total_freight_value,
            SUM(p.product_weight_g) as total_weight_g,
            SUM(p.product_length_cm * p.product_height_cm * p.product_width_cm) as total_volume_cm3,
            COUNT(*) as item_count,
            -- Hay órdenes con múltiples sellers, para ellos calculamos la latitud y longitud promedio.
            -- No es ideal pero es un compromiso razonable.
            AVG(geo_seller.lat) as avg_lat_seller,
            AVG(geo_seller.lng) as avg_lng_seller,
            -- Para el estado del seller también hacemos un compromiso agarrando el primero en orden alfabético.
            MIN(s.seller_state) as seller_state
        FROM order_items i
        JOIN products p ON i.product_id = p.product_id
        JOIN sellers s ON i.seller_id = s.seller_id
        LEFT JOIN geo_agg geo_seller ON s.seller_zip_code_prefix = geo_seller.geolocation_zip_code_prefix
        -- Filtramos los productos que no tengan datos de peso o dimensiones.
        WHERE p.product_weight_g IS NOT NULL
          AND p.product_length_cm IS NOT NULL
          AND p.product_height_cm IS NOT NULL
          AND p.product_width_cm IS NOT NULL
        GROUP BY i.order_id
    )
    SELECT
        o.order_id,
        o.order_purchase_timestamp,
        o.order_delivered_customer_date,
        a.total_price,
        a.total_freight_value,
        a.total_weight_g,
        a.total_volume_cm3,
        a.item_count,
        c.customer_state,
        a.seller_state,
        geo_customer.lat as lat_customer,
        geo_customer.lng as lng_customer,
        a.avg_lat_seller as lat_seller,
        a.avg_lng_seller as lng_seller
    FROM orders o
    JOIN item_agg a ON o.order_id = a.order_id
    JOIN customers c ON o.customer_id = c.customer_id
    LEFT JOIN geo_agg geo_customer ON c.customer_zip_code_prefix = geo_customer.geolocation_zip_code_prefix
    -- Solo nos interesan las órdenes que fueron entregadas.
    WHERE o.order_status = 'delivered'
      -- También filtramos las órdenes que no tengan ciertos datos.
      AND o.order_delivered_customer_date IS NOT NULL
      AND geo_customer.lat IS NOT NULL
      AND a.avg_lat_seller IS NOT NULL
    """

    df = pd.read_sql(query, conn)

df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"])
df["order_delivered_customer_date"] = pd.to_datetime(df["order_delivered_customer_date"])

# Calculamos la distancia entre el cliente y el seller mediante distancia geodésica.
df["distance_km"] = df.apply(
    lambda row: geodesic((row["lat_customer"], row["lng_customer"]), (row["lat_seller"], row["lng_seller"])).kilometers,
    axis=1,
)

# Variable objetivo: días que se tardó en entregar la orden.
df["actual_delivery_days"] = (
    df["order_delivered_customer_date"] - df["order_purchase_timestamp"]
).dt.total_seconds() / 86400

# Características temporales adicionales
df["purchase_month"] = df["order_purchase_timestamp"].dt.month
df["purchase_day_of_week"] = df["order_purchase_timestamp"].dt.dayofweek
df["purchase_hour"] = df["order_purchase_timestamp"].dt.hour

df["delivery_month"] = df["order_delivered_customer_date"].dt.month
df["delivery_day_of_week"] = df["order_delivered_customer_date"].dt.dayofweek
df["delivery_hour"] = df["order_delivered_customer_date"].dt.hour


display(df.head())
display(df.info())
# Out:
#                            order_id order_purchase_timestamp  \
# 0  00010242fe8c5a6d1ba2dd792cb16214      2017-09-13 08:59:02
# 1  00018f77f2f0320c557190d7a144bdd3      2017-04-26 10:53:06
# 2  000229ec398224ef6ca0657da4fc703e      2018-01-14 14:33:31
# 3  00024acbcdf0a6daa1e931b038114c75      2018-08-08 10:00:35
# 4  00042b26cf59d7ce69dfabb4e55b4fd9      2017-02-04 13:57:51
#
#   order_delivered_customer_date  total_price  total_freight_value  \
# 0           2017-09-20 23:43:48        58.90                13.29
# 1           2017-05-12 16:04:24       239.90                19.93
# 2           2018-01-22 13:19:16       199.00                17.87
# 3           2018-08-14 13:32:39        12.99                12.79
# 4           2017-03-01 16:42:31       199.90                18.14
#
#    total_weight_g  total_volume_cm3  item_count customer_state seller_state  \
# 0           650.0            3528.0           1             RJ           SP
# 1         30000.0           60000.0           1             SP           SP
# 2          3050.0           14157.0           1             MG           MG
# 3           200.0            2400.0           1             SP           SP
# 4          3750.0           42000.0           1             SP           PR
#
#    ...  lat_seller  lng_seller  distance_km  actual_delivery_days  \
# 0  ...  -22.496953  -44.127492   301.858959              7.614421
# 1  ...  -23.565096  -46.518565   585.131104             16.216181
# 2  ...  -22.262584  -46.171124   311.506212              7.948437
# 3  ...  -20.553624  -47.387359   292.064162              6.147269
# 4  ...  -22.929384  -53.135873   647.209811             25.114352
#
#    purchase_month  purchase_day_of_week  purchase_hour  delivery_month  \
# 0               9                     2              8               9
# 1               4                     2             10               5
# 2               1                     6             14               1
# 3               8                     2             10               8
# 4               2                     5             13               3
#
#    delivery_day_of_week  delivery_hour
# 0                     2             23
# 1                     4             16
# 2                     0             13
# 3                     1             13
# 4                     2             16
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95978 entries, 0 to 95977
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       95978 non-null  object
#  1   order_purchase_timestamp       95978 non-null  datetime64[ns]
#  2   order_delivered_customer_date  95978 non-null  datetime64[ns]
#  3   total_price                    95978 non-null  float64
#  4   total_freight_value            95978 non-null  float64
#  5   total_weight_g                 95978 non-null  float64
#  6   total_volume_cm3               95978 non-null  float64
#  7   item_count                     95978 non-null  int64
#  8   customer_state                 95978 non-null  object
#  9   seller_state                   95978 non-null  object
#  10  lat_customer                   95978 non-null  float64
#  11  lng_customer                   95978 non-null  float64
#  12  lat_seller                     95978 non-null  float64
#  13  lng_seller                     95978 non-null  float64
#  14  distance_km                    95978 non-null  float64
#  15  actual_delivery_days           95978 non-null  float64
#  16  purchase_month                 95978 non-null  int32
#  17  purchase_day_of_week           95978 non-null  int32
#  18  purchase_hour                  95978 non-null  int32
#  19  delivery_month                 95978 non-null  int32
#  20  delivery_day_of_week           95978 non-null  int32
#  21  delivery_hour                  95978 non-null  int32
# dtypes: datetime64[ns](2), float64(10), int32(6), int64(1), object(3)
# memory usage: 13.9+ MB
# None

# %% [markdown]
# Con este último `df.info()` podemos ver que se obtuvo el _dataset_ de forma correcta.
#
# ## Análisis Exploratorio de Datos (EDA)
#
# ### Estadísticas descriptivas
#
# Primero creamos algunos objetos que nos serán útiles para el análisis:

# %%
# Diccionario para mapear nombres de columnas a nombres legibles
column_names = {
    "order_id": "ID de Orden",
    "order_purchase_timestamp": "Fecha de Compra",
    "order_delivered_customer_date": "Fecha de Entrega",
    "total_price": "Precio Total",
    "total_freight_value": "Costo de Envío",
    "total_weight_g": "Peso Total (g)",
    "total_volume_cm3": "Volumen Total (cm³)",
    "item_count": "Cantidad de Items",
    "customer_state": "Estado del Cliente",
    "seller_state": "Estado del Vendedor",
    "lat_customer": "Latitud Cliente",
    "lng_customer": "Longitud Cliente",
    "lat_seller": "Latitud Vendedor",
    "lng_seller": "Longitud Vendedor",
    "distance_km": "Distancia (km)",
    "actual_delivery_days": "Días de Entrega",
    "purchase_month": "Mes de Compra",
    "purchase_day_of_week": "Día de la Semana de Compra",
    "purchase_hour": "Hora de Compra",
    "delivery_month": "Mes de Entrega",
    "delivery_day_of_week": "Día de la Semana de Entrega",
    "delivery_hour": "Hora de Entrega",
}

# %% [markdown]
# ### Distribución del tiempo de entrega
#
# Analicemos la distribución de nuestra variable objetivo:

# %%
# Configuración de estilo de los plots
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Histograma
axes[0].hist(df["actual_delivery_days"], bins=50, edgecolor="black", alpha=0.7)
axes[0].set_xlabel(column_names["actual_delivery_days"])
axes[0].set_ylabel("Frecuencia")
axes[0].set_title(f"Distribución de {column_names['actual_delivery_days']}")
axes[0].axvline(
    df["actual_delivery_days"].median(),
    color="red",
    linestyle="--",
    label=f"Mediana: {df['actual_delivery_days'].median():.1f} días",
)
axes[0].axvline(
    df["actual_delivery_days"].mean(),
    color="orange",
    linestyle="--",
    label=f"Media: {df['actual_delivery_days'].mean():.1f} días",
)
axes[0].legend()

# Box plot
axes[1].boxplot(df["actual_delivery_days"])
axes[1].set_ylabel(column_names["actual_delivery_days"])
axes[1].set_title(f"Box Plot de {column_names['actual_delivery_days']}")
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis de la distribución
#
# La distribución de tiempos de entrega muestra un patrón interesante:
#
# - La **mediana es de 10.2 días** mientras que la **media es de 12.5 días**, indicando una distribución sesgada hacia la derecha (cola larga).
# - La mayoría de las entregas se concentran entre **7 y 15 días**.
# - Existe una cantidad significativa de **outliers** (entregas que tomaron más de 30 días), visible en el box plot.
# - El pico de la distribución está alrededor de los **8-10 días**, sugiriendo que este es el tiempo "típico" de entrega para Olist.
#
# Un dato interesante es que algunas entregas tomaron más de 200 días. Estas podrían ser casos especiales, devoluciones, o problemas logísticos que vale la pena investigar más a fondo.
#
# ### Análisis temporal - Distribución de cantidades
#
# Ahora veamos la distribución de la **cantidad** de compras y entregas por período temporal:

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# ===== Cantidad por fecha de compra =====
# Por mes de compra
count_by_month = df.groupby("purchase_month").size()
axes[0, 0].bar(count_by_month.index, count_by_month.values, color="steelblue", edgecolor="black")
axes[0, 0].set_xlabel(column_names["purchase_month"])
axes[0, 0].set_ylabel("Cantidad de Órdenes")
axes[0, 0].set_title(f"Cantidad de Órdenes por {column_names['purchase_month']}")
axes[0, 0].grid(True, alpha=0.3, axis="y")
axes[0, 0].set_xticks(range(1, 13))

# Por día de la semana de compra
count_by_dow = df.groupby("purchase_day_of_week").size()
day_names = ["Lun", "Mar", "Mié", "Jue", "Vie", "Sáb", "Dom"]
axes[0, 1].bar(range(7), count_by_dow.values, color="steelblue", edgecolor="black")
axes[0, 1].set_xlabel(column_names["purchase_day_of_week"])
axes[0, 1].set_ylabel("Cantidad de Órdenes")
axes[0, 1].set_title(f"Cantidad de Órdenes por {column_names['purchase_day_of_week']}")
axes[0, 1].set_xticks(range(7))
axes[0, 1].set_xticklabels(day_names)
axes[0, 1].grid(True, alpha=0.3, axis="y")

# Por hora de compra
count_by_hour = df.groupby("purchase_hour").size()
axes[0, 2].bar(count_by_hour.index, count_by_hour.values, color="steelblue", edgecolor="black")
axes[0, 2].set_xlabel(column_names["purchase_hour"])
axes[0, 2].set_ylabel("Cantidad de Órdenes")
axes[0, 2].set_title(f"Cantidad de Órdenes por {column_names['purchase_hour']}")
axes[0, 2].grid(True, alpha=0.3, axis="y")
axes[0, 2].set_xticks(range(0, 24, 2))

# ===== Cantidad por fecha de entrega =====
# Por mes de entrega
count_by_delivery_month = df.groupby("delivery_month").size()
axes[1, 0].bar(count_by_delivery_month.index, count_by_delivery_month.values, color="coral", edgecolor="black")
axes[1, 0].set_xlabel(column_names["delivery_month"])
axes[1, 0].set_ylabel("Cantidad de Entregas")
axes[1, 0].set_title(f"Cantidad de Entregas por {column_names['delivery_month']}")
axes[1, 0].grid(True, alpha=0.3, axis="y")
axes[1, 0].set_xticks(range(1, 13))

# Por día de la semana de entrega
count_by_delivery_dow = df.groupby("delivery_day_of_week").size()
axes[1, 1].bar(range(7), count_by_delivery_dow.values, color="coral", edgecolor="black")
axes[1, 1].set_xlabel(column_names["delivery_day_of_week"])
axes[1, 1].set_ylabel("Cantidad de Entregas")
axes[1, 1].set_title(f"Cantidad de Entregas por {column_names['delivery_day_of_week']}")
axes[1, 1].set_xticks(range(7))
axes[1, 1].set_xticklabels(day_names)
axes[1, 1].grid(True, alpha=0.3, axis="y")

# Por hora de entrega
count_by_delivery_hour = df.groupby("delivery_hour").size()
axes[1, 2].bar(count_by_delivery_hour.index, count_by_delivery_hour.values, color="coral", edgecolor="black")
axes[1, 2].set_xlabel(column_names["delivery_hour"])
axes[1, 2].set_ylabel("Cantidad de Entregas")
axes[1, 2].set_title(f"Cantidad de Entregas por {column_names['delivery_hour']}")
axes[1, 2].grid(True, alpha=0.3, axis="y")
axes[1, 2].set_xticks(range(0, 24, 2))

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis de patrones temporales
#
# Los gráficos revelan patrones interesantes sobre cuándo los brasileños compran y reciben sus pedidos:
#
# **Patrones de compra (azul):**
# - **Pico en mayo** (~10,000 órdenes) y **valle en septiembre** (~4,000 órdenes), sugiriendo estacionalidad fuerte.
# - Las compras son **bastante uniformes durante la semana**, con un ligero descenso el fin de semana.
# - El **horario principal de compras es de 10 AM a 10 PM**, con muy pocas compras de madrugada (0-6 AM).
# - Un dato interesante es que el pico de compras ocurre a las 3 PM, lo que sugiere que los brasileños aprovechan la pausa del almuerzo o la tarde para realizar compras online.
#
# **Patrones de entrega (naranja):**
# - Las entregas siguen un patrón similar a las compras por mes, con **pico en agosto** (~13,000 entregas).
# - **Lunes a miércoles** tienen más entregas que el resto de la semana.
# - **Sábados tienen muy pocas entregas** (~5,000) y **domingos casi ninguna** (~1,000), confirmando que la logística en Brasil opera principalmente en días laborales.
# - Las entregas se concentran entre **3 PM y 8 PM** (~10,000 por hora), el horario en que la gente suele estar en casa después del trabajo.
# - La gran mayoría de entregas ocurre en horario vespertino (3-8 PM), como se puede observar claramente en este gráfico. Es importante notar que las entregas en horarios inusuales (como 5-6 AM) representan solo una pequeña fracción del total (menos del 3%).
#
# ### Correlación con variables numéricas
#
# Veamos cómo se correlacionan las variables numéricas con el tiempo de entrega:

# %%
# Seleccionamos solo las columnas numéricas relevantes
numeric_cols = [
    "actual_delivery_days",
    "distance_km",
    "total_price",
    "total_freight_value",
    "total_weight_g",
    "total_volume_cm3",
    "item_count",
]

correlation_matrix = df[numeric_cols].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(
    correlation_matrix.rename(columns=column_names, index=column_names),
    annot=True,
    fmt=".3f",
    cmap="coolwarm",
    center=0,
    square=True,
    linewidths=1,
    cbar_kws={"shrink": 0.8},
)
plt.title("Matriz de Correlación")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis de correlaciones
#
# La matriz de correlación revela información crucial para el modelo de predicción:
#
# - **Distancia (km)** tiene la correlación más fuerte con días de entrega (**0.394**), confirmando que ubicación geográfica es un predictor clave.
# - **Costo de envío** muestra correlación moderada (**0.167**), aunque es interesante que sea menor que distancia.
# - **Peso y volumen están altamente correlacionados entre sí** (0.830), lo cual tiene sentido físico y sugiere que podríamos usar solo una de estas variables para evitar multicolinealidad.
# - **Precio total** tiene correlación baja con tiempo de entrega (**0.056**), indicando que productos más caros no necesariamente llegan más rápido.
# - **Cantidad de items** tiene correlación casi nula (**-0.019**), lo que sorprende un poco.
#
# Un dato interesante es que el costo de envío está más correlacionado con peso/volumen (0.64) que con distancia (0.315). Esto sugiere que Olist cobra más por paquetes grandes que por distancia larga.
#
# ### Relación entre distancia y tiempo de entrega

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df["distance_km"], df["actual_delivery_days"], alpha=0.3, s=10)
plt.xlabel(column_names["distance_km"])
plt.ylabel(column_names["actual_delivery_days"])
plt.title(f"Relación entre {column_names['distance_km']} y {column_names['actual_delivery_days']}")
plt.grid(True, alpha=0.3)

# Agregar línea de tendencia
z = np.polyfit(df["distance_km"], df["actual_delivery_days"], 1)
p = np.poly1d(z)
plt.plot(
    df["distance_km"].sort_values(),
    p(df["distance_km"].sort_values()),
    "r--",
    linewidth=2,
    label=f"Tendencia: y={z[0]:.4f}x+{z[1]:.2f}",
)
plt.legend()
plt.show()

# %% [markdown]
# #### Análisis de distancia vs. tiempo
#
# El gráfico de dispersión muestra una relación clara pero con mucha variabilidad:
#
# - La **línea de tendencia** (y = 0.0064x + 8.74) indica que por cada **1000 km adicionales**, el tiempo de entrega aumenta aproximadamente **6.4 días**.
# - Hay una **nube densa de puntos cerca de distancias cortas** (0-1000 km), donde la mayoría de entregas ocurren.
# - **Gran dispersión vertical**: dos órdenes con la misma distancia pueden tener tiempos de entrega muy diferentes (±20 días), sugiriendo que otros factores (infraestructura, clima, eficiencia del vendedor) también son importantes.
# - Algunos puntos extremos muestran entregas con **distancias muy largas** (>4000 km), que podrían ser rutas indirectas, errores de datos, o casos donde el vendedor tiene múltiples almacenes.
#
# Un dato interesante es que el intercepto de 8.74 días sugiere que incluso una entrega de "distancia cero" (misma ciudad) tomaría aproximadamente 9 días en promedio. Esto revela el tiempo base de procesamiento y logística interna inherente al sistema.
#
# ### Análisis por estado del cliente

# %%
# Tiempo de entrega promedio por estado del cliente
delivery_by_customer_state = (
    df.groupby("customer_state")["actual_delivery_days"]
    .agg(["mean", "median", "count"])
    .sort_values("mean", ascending=False)
)

plt.figure(figsize=(14, 6))
delivery_by_customer_state["mean"].plot(kind="bar", color="steelblue", edgecolor="black")
plt.xlabel(column_names["customer_state"])
plt.ylabel(f"{column_names['actual_delivery_days']} (promedio)")
plt.title(f"{column_names['actual_delivery_days']} Promedio por {column_names['customer_state']}")
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

print("\nTop 10 estados con mayor tiempo de entrega:")
display(delivery_by_customer_state.head(10))
# Out:
# Top 10 estados con mayor tiempo de entrega:
#                      mean     median  count
# customer_state
# RR              29.387546  25.007303     41
# AP              27.185068  24.347025     67
# AM              26.425991  25.875139    145
# AL              24.569154  22.392737    396
# PA              23.787993  21.078391    944
# SE              21.511108  17.985775    334
# MA              21.496541  19.135046    713
# CE              21.299953  18.210712   1272
# AC              21.157493  18.379433     79
# PB              20.488391  18.204606    511

# %% [markdown]
# #### Análisis por ubicación del cliente
#
# La geografía del cliente tiene un impacto dramático en los tiempos de entrega:
#
# - **RR (Roraima), AP (Amapá), y AM (Amazonas)** lideran con ~29, 27, y 26 días respectivamente. Estos son estados remotos en la región amazónica del norte.
# - **SP (São Paulo)** tiene el tiempo más corto (~8.6 días), siendo el centro económico y logístico de Brasil.
# - Hay una diferencia de **más de 3x** entre el estado más rápido y el más lento.
# - Estados del **sureste (SP, MG, RJ)** consistentemente tienen entregas rápidas (8-13 días), mientras que el **norte remoto** sufre tiempos largos.
#
# Un dato interesante es que la diferencia entre SP y RR es de aproximadamente 20 días. Esto evidencia el enorme desafío logístico de cubrir un país del tamaño de Brasil, donde la infraestructura varía dramáticamente por región.
#
# ### Análisis por estado del vendedor

# %%
# Tiempo de entrega promedio por estado del seller
delivery_by_seller_state = (
    df.groupby("seller_state")["actual_delivery_days"]
    .agg(["mean", "median", "count"])
    .sort_values("mean", ascending=False)
)

plt.figure(figsize=(14, 6))
delivery_by_seller_state["mean"].plot(kind="bar", color="coral", edgecolor="black")
plt.xlabel(column_names["seller_state"])
plt.ylabel(f"{column_names['actual_delivery_days']} (promedio)")
plt.title(f"{column_names['actual_delivery_days']} Promedio por {column_names['seller_state']}")
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

print("\nTop 10 estados de vendedores con mayor tiempo de entrega:")
display(delivery_by_seller_state.head(10))
# Out:
# Top 10 estados de vendedores con mayor tiempo de entrega:
#                    mean     median  count
# seller_state
# AM            47.840802  29.523484      3
# RO            18.409815  17.902072     13
# MA            17.714208  15.718356    387
# CE            17.532968  14.133368     86
# MT            14.747999  12.977454    136
# PI            13.917969  13.432517     10
# BA            13.867704  11.765197    545
# SC            13.739066  11.734404   3570
# PA            13.427086  12.665781      8
# PR            13.398947  11.203183   7470

# %% [markdown]
# #### Análisis por ubicación del vendedor
#
# La ubicación del vendedor también influye significativamente:
#
# - **AM (Amazonas)** lidera con ~48 días promedio, casi el doble que el segundo lugar. Esto muestra lo difícil que es enviar productos desde la región amazónica.
# - **RO (Rondônia), MA (Maranhão), y CE (Ceará)** también muestran tiempos largos (18-17 días).
# - La mayoría de los estados tienen tiempos entre **11-14 días**, mucho más homogéneos que por estado del cliente.
# - **RS (Rio Grande do Sul)** tiene el mejor tiempo (~11 días), seguido por estados del sureste.
#
# Un dato interesante es la diferencia entre vendedor y cliente. AM como vendedor toma 48 días en promedio, mientras que AM como cliente solo 26 días. Esto sugiere que es mucho más difícil enviar productos desde el Amazonas que recibirlos allí. Probablemente la mayoría de vendedores están ubicados en el sureste y ya tienen rutas logísticas establecidas hacia el norte.
#
# ### Análisis temporal
#
# Analizamos patrones temporales tanto en la fecha de compra como en la fecha de entrega:

# %%
# Análisis temporal de compra
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# ===== Análisis por fecha de compra =====
# Por mes de compra
delivery_by_month = df.groupby("purchase_month")["actual_delivery_days"].mean()
axes[0, 0].plot(delivery_by_month.index, delivery_by_month.values, marker="o", linewidth=2, markersize=8)
axes[0, 0].set_xlabel(column_names["purchase_month"])
axes[0, 0].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[0, 0].set_title(f"{column_names['actual_delivery_days']} por {column_names['purchase_month']}")
axes[0, 0].grid(True, alpha=0.3)
axes[0, 0].set_xticks(range(1, 13))

# Por día de la semana de compra
delivery_by_dow = df.groupby("purchase_day_of_week")["actual_delivery_days"].mean()
day_names = ["Lun", "Mar", "Mié", "Jue", "Vie", "Sáb", "Dom"]
axes[0, 1].bar(range(7), delivery_by_dow.values, color="steelblue", edgecolor="black")
axes[0, 1].set_xlabel(column_names["purchase_day_of_week"])
axes[0, 1].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[0, 1].set_title(f"{column_names['actual_delivery_days']} por {column_names['purchase_day_of_week']}")
axes[0, 1].set_xticks(range(7))
axes[0, 1].set_xticklabels(day_names)
axes[0, 1].grid(True, alpha=0.3, axis="y")

# Por hora de compra
delivery_by_hour = df.groupby("purchase_hour")["actual_delivery_days"].mean()
axes[0, 2].plot(delivery_by_hour.index, delivery_by_hour.values, marker="o", linewidth=2, markersize=6)
axes[0, 2].set_xlabel(column_names["purchase_hour"])
axes[0, 2].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[0, 2].set_title(f"{column_names['actual_delivery_days']} por {column_names['purchase_hour']}")
axes[0, 2].grid(True, alpha=0.3)
axes[0, 2].set_xticks(range(0, 24, 2))

# ===== Análisis por fecha de entrega =====
# Por mes de entrega
delivery_by_delivery_month = df.groupby("delivery_month")["actual_delivery_days"].mean()
axes[1, 0].plot(
    delivery_by_delivery_month.index,
    delivery_by_delivery_month.values,
    marker="o",
    linewidth=2,
    markersize=8,
    color="coral",
)
axes[1, 0].set_xlabel(column_names["delivery_month"])
axes[1, 0].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[1, 0].set_title(f"{column_names['actual_delivery_days']} por {column_names['delivery_month']}")
axes[1, 0].grid(True, alpha=0.3)
axes[1, 0].set_xticks(range(1, 13))

# Por día de la semana de entrega
delivery_by_delivery_dow = df.groupby("delivery_day_of_week")["actual_delivery_days"].mean()
axes[1, 1].bar(range(7), delivery_by_delivery_dow.values, color="coral", edgecolor="black")
axes[1, 1].set_xlabel(column_names["delivery_day_of_week"])
axes[1, 1].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[1, 1].set_title(f"{column_names['actual_delivery_days']} por {column_names['delivery_day_of_week']}")
axes[1, 1].set_xticks(range(7))
axes[1, 1].set_xticklabels(day_names)
axes[1, 1].grid(True, alpha=0.3, axis="y")

# Por hora de entrega
delivery_by_delivery_hour = df.groupby("delivery_hour")["actual_delivery_days"].mean()
axes[1, 2].plot(
    delivery_by_delivery_hour.index,
    delivery_by_delivery_hour.values,
    marker="o",
    linewidth=2,
    markersize=6,
    color="coral",
)
axes[1, 2].set_xlabel(column_names["delivery_hour"])
axes[1, 2].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[1, 2].set_title(f"{column_names['actual_delivery_days']} por {column_names['delivery_hour']}")
axes[1, 2].grid(True, alpha=0.3)
axes[1, 2].set_xticks(range(0, 24, 2))

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis de patrones temporales (tiempos de entrega)
#
# Estos gráficos muestran **cómo el momento de compra/entrega afecta la duración** del envío:
#
# **Por mes:**
# - **Febrero** tiene el pico más alto (~16.5 días para compras), posiblemente por el carnaval brasileño que afecta la logística.
# - **Agosto** es el más eficiente (~9 días), aunque paradójicamente es cuando más entregas ocurren.
# - La diferencia estacional es de **~7 días** entre el mejor y peor mes.
#
# **Por día de la semana:**
# - Compras de **viernes-sábado** toman ligeramente más tiempo que compras de lunes-martes, aunque la diferencia es pequeña.
# - Entregas en **domingo** toman más tiempo en promedio (~14.5 días), pero recordemos que hay muy pocas entregas dominicales.
#
# **Por hora:**
# - Compras muy temprano (0-2 AM) o muy tarde (11 PM-midnight) toman **~1 día más** que compras en horario normal.
# - El **pico a las 5-6 AM en entregas** que vimos antes ahora tiene sentido: esas ~3,000 entregas matutinas tomaron **~15 días** en promedio, mucho más que el promedio general. Son probablemente casos especiales o entregas problemáticas.
# - Entregas en horario vespertino (4-8 PM) correlacionan con tiempos más cortos (~12.5 días).
#
# Un dato interesante es que comprar a las 4 AM reduce el tiempo de entrega en aproximadamente 1.5 días comparado con comprar a medianoche. Esto probablemente se debe a que los sistemas procesan pedidos en lotes matutinos, por lo que las compras de madrugada entran en el primer lote de procesamiento del día.
#
# ### Análisis de outliers (IQR)
#
# Con este código hacemos un análisis de outliers en la variable objetivo `actual_delivery_days` utilizando el método del Rango Intercuartílico (IQR).

# %%
Q1 = df["actual_delivery_days"].quantile(0.25)
Q3 = df["actual_delivery_days"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df["actual_delivery_days"] < lower_bound) | (df["actual_delivery_days"] > upper_bound)]

print(f"""
Análisis de Outliers:
  Límite inferior: {lower_bound:.2f} días
  Límite superior: {upper_bound:.2f} días
  Número de outliers: {len(outliers)} ({len(outliers) / len(df) * 100:.2f}%)
  Rango de outliers: {outliers["actual_delivery_days"].min():.2f} - {outliers["actual_delivery_days"].max():.2f} días
""")
# Out:
# Análisis de Outliers:
#   Límite inferior: -6.66 días
#   Límite superior: 29.12 días
#   Número de outliers: 4891 (5.10%)
#   Rango de outliers: 29.12 - 209.63 días

# %% [markdown]
# ## Ingeniería de Características
#
# Basándonos en los _insights_ del análisis exploratorio, vamos a crear nuevas características que podrían mejorar el poder predictivo de nuestro modelo.
#
# ### Justificación de las nuevas características
#
# Del análisis exploratorio aprendimos que:
#
# 1. **La distancia** tiene la correlación más fuerte (0.394) con el tiempo de entrega, pero la relación podría no ser completamente lineal.
# 2. **La ubicación geográfica** (estados) tiene un impacto dramático - diferencias de hasta 3x entre regiones.
# 3. **Los estados remotos del norte** (RR, AP, AM) tienen tiempos significativamente más largos.
# 4. **El sureste** (SP, RJ, MG) consistentemente tiene entregas más rápidas por su infraestructura logística.
# 5. **Patrones temporales** muestran efectos marginales en fin de semana y horario, pero sí hay estacionalidad mensual.
# 6. **Peso y volumen** están altamente correlacionados (0.830), sugiriendo que su relación (densidad) podría ser más informativa.
#
# Por lo tanto, crearemos características que capturen estos patrones de manera más efectiva:
#
# ### Creación de nuevas features
#
# #### Feature 1: categoría de distancia
#
# Categorizamos la distancia en rangos para capturar relaciones no lineales. El impacto de 100km adicionales probablemente es diferente entre 0-100km que entre 1000-1100km.

# %%
df["distance_category"] = pd.cut(
    df["distance_km"],
    bins=[0, 100, 500, 1000, float("inf")],
    labels=["local", "regional", "long_distance", "very_long_distance"],
)

print(f"""
Distribución de categorías de distancia:
{df["distance_category"].value_counts().sort_index()}
""")
# Out:
# Distribución de categorías de distancia:
# distance_category
# local                 17852
# regional              37123
# long_distance         25678
# very_long_distance    15302
# Name: count, dtype: int64

# %% [markdown]
# #### Feature 2: mismo estado
#
# Creamos un indicador de si el cliente y vendedor están en el mismo estado. Las entregas intra-estatales son típicamente más rápidas por no cruzar fronteras administrativas y usar logística local.

# %%
df["same_state"] = (df["customer_state"] == df["seller_state"]).astype(int)

print(f"""
Órdenes en el mismo estado:
  Total: {df["same_state"].sum()} órdenes
  Porcentaje: {df["same_state"].mean() * 100:.1f}%
""")
# Out:
# Órdenes en el mismo estado:
#   Total: 34567 órdenes
#   Porcentaje: 36.0%

# %% [markdown]
# #### Feature 3: densidad
#
# Calculamos la densidad (peso por volumen) para capturar la relación entre peso y volumen evitando multicolinealidad. Productos densos vs voluminosos podrían tener diferentes costos y tiempos logísticos.

# %%
df["density"] = df["total_weight_g"] / df["total_volume_cm3"]

print(f"""
Estadísticas de densidad (g/cm³):
  Media: {df["density"].mean():.2f}
  Mediana: {df["density"].median():.2f}
  Desviación estándar: {df["density"].std():.2f}
""")
# Out:
# Estadísticas de densidad (g/cm³):
#   Media: 0.19
#   Mediana: 0.11
#   Desviación estándar: 0.71

# %% [markdown]
# #### Feature 4: precio por item
#
# Calculamos el precio unitario por item. Productos de alto valor unitario podrían recibir tratamiento logístico diferente (más cuidado, rutas específicas).

# %%
df["price_per_item"] = df["total_price"] / df["item_count"]

print(f"""
Estadísticas de precio por item (R$):
  Media: {df["price_per_item"].mean():.2f}
  Mediana: {df["price_per_item"].median():.2f}
  Mínimo: {df["price_per_item"].min():.2f}
  Máximo: {df["price_per_item"].max():.2f}
""")
# Out:
# Estadísticas de precio por item (R$):
#   Media: 125.26
#   Mediana: 79.00
#   Mínimo: 0.85
#   Máximo: 6735.00

# %% [markdown]
# #### Feature 5: costo de envío por kilómetro
#
# Normalizamos el costo de envío por distancia para revelar si ciertos envíos son más "caros" relativamente y podrían recibir prioridad.

# %%
df["freight_per_km"] = df["total_freight_value"] / (df["distance_km"] + 1)

print(f"""
Estadísticas de costo de envío por km (R$/km):
  Media: {df["freight_per_km"].mean():.2f}
  Mediana: {df["freight_per_km"].median():.2f}
  Percentil 95: {df["freight_per_km"].quantile(0.95):.2f}
""")
# Out:
# Estadísticas de costo de envío por km (R$/km):
#   Media: 0.17
#   Mediana: 0.04
#   Percentil 95: 0.67

# %% [markdown]
# #### Feature 6: región remota
#
# Creamos indicadores para regiones remotas del norte. El análisis mostró que RR, AP, AM tienen tiempos 2-3x más largos que el promedio nacional debido a infraestructura limitada.

# %%
remote_states = ["RR", "AP", "AM", "AC", "RO", "PA"]
df["customer_remote"] = df["customer_state"].isin(remote_states).astype(int)
df["seller_remote"] = df["seller_state"].isin(remote_states).astype(int)

print(f"""
Clientes en región remota:
  Total: {df["customer_remote"].sum()} clientes
  Porcentaje: {df["customer_remote"].mean() * 100:.1f}%

Vendedores en región remota:
  Total: {df["seller_remote"].sum()} vendedores
  Porcentaje: {df["seller_remote"].mean() * 100:.1f}%
""")
# Out:
# Clientes en región remota:
#   Total: 1516 clientes
#   Porcentaje: 1.6%
#
# Vendedores en región remota:
#   Total: 24 vendedores
#   Porcentaje: 0.0%

# %% [markdown]
# #### Feature 7: región sureste
#
# Creamos indicadores para la región sureste. SP, RJ, MG, ES consistentemente mostraron los tiempos más cortos por ser el centro económico y logístico de Brasil.

# %%
southeast_states = ["SP", "RJ", "MG", "ES"]
df["customer_southeast"] = df["customer_state"].isin(southeast_states).astype(int)
df["seller_southeast"] = df["seller_state"].isin(southeast_states).astype(int)

print(f"""
Clientes en región sureste:
  Total: {df["customer_southeast"].sum()} clientes
  Porcentaje: {df["customer_southeast"].mean() * 100:.1f}%

Vendedores en región sureste:
  Total: {df["seller_southeast"].sum()} vendedores
  Porcentaje: {df["seller_southeast"].mean() * 100:.1f}%
""")
# Out:
# Clientes en región sureste:
#   Total: 65999 clientes
#   Porcentaje: 68.8%
#
# Vendedores en región sureste:
#   Total: 80041 vendedores
#   Porcentaje: 83.4%

# %% [markdown]
# #### Feature 8: compra en fin de semana
#
# Creamos un indicador de compras en fin de semana. El análisis posterior mostró que el efecto del fin de semana es marginal (~0.1 días extra).

# %%
df["purchase_weekend"] = (df["purchase_day_of_week"] >= 5).astype(int)

print(f"""
Compras en fin de semana:
  Total: {df["purchase_weekend"].sum()} compras
  Porcentaje: {df["purchase_weekend"].mean() * 100:.1f}%
""")
# Out:
# Compras en fin de semana:
#   Total: 22066 compras
#   Porcentaje: 23.0%

# %% [markdown]
# #### Feature 9: compra en horario laboral
#
# Creamos un indicador de compras en horario laboral (9 AM - 6 PM). El análisis posterior mostró que este efecto también es marginal (~0.06 días).

# %%
df["purchase_business_hours"] = ((df["purchase_hour"] >= 9) & (df["purchase_hour"] <= 18)).astype(int)

print(f"""
Compras en horario laboral:
  Total: {df["purchase_business_hours"].sum()} compras
  Porcentaje: {df["purchase_business_hours"].mean() * 100:.1f}%
""")
# Out:
# Compras en horario laboral:
#   Total: 59472 compras
#   Porcentaje: 62.0%

# %% [markdown]
# ### Actualizar diccionario de nombres

# %%
# Agregamos las columnas nuevas al diccionario de nombres
column_names.update(
    {
        "distance_category": "Categoría de Distancia",
        "same_state": "Mismo Estado",
        "density": "Densidad (g/cm³)",
        "price_per_item": "Precio por Item",
        "freight_per_km": "Costo de Envío por km",
        "customer_remote": "Cliente en Región Remota",
        "seller_remote": "Vendedor en Región Remota",
        "customer_southeast": "Cliente en Sureste",
        "seller_southeast": "Vendedor en Sureste",
        "purchase_weekend": "Compra en Fin de Semana",
        "purchase_business_hours": "Compra en Horario Laboral",
    }
)

# %% [markdown]
# ### Análisis de las nuevas características
#
# Veamos cómo estas nuevas características se relacionan con el tiempo de entrega:

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Tiempo de entrega por categoría de distancia
distance_cat_delivery = df.groupby("distance_category", observed=False)["actual_delivery_days"].mean()
axes[0, 0].bar(range(len(distance_cat_delivery)), distance_cat_delivery.values, color="steelblue", edgecolor="black")
axes[0, 0].set_xlabel(column_names["distance_category"])
axes[0, 0].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[0, 0].set_title(f"{column_names['actual_delivery_days']} por {column_names['distance_category']}")
axes[0, 0].set_xticks(range(len(distance_cat_delivery)))
axes[0, 0].set_xticklabels(distance_cat_delivery.index, rotation=45)
axes[0, 0].grid(True, alpha=0.3, axis="y")

# 2. Tiempo de entrega: mismo estado vs diferente estado
same_state_delivery = df.groupby("same_state")["actual_delivery_days"].mean()
axes[0, 1].bar(["Diferente Estado", "Mismo Estado"], same_state_delivery.values, color="coral", edgecolor="black")
axes[0, 1].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[0, 1].set_title(f"{column_names['actual_delivery_days']} por {column_names['same_state']}")
axes[0, 1].grid(True, alpha=0.3, axis="y")

# 3. Densidad vs tiempo de entrega (scatter)
axes[0, 2].scatter(df["density"], df["actual_delivery_days"], alpha=0.3, s=10)
axes[0, 2].set_xlabel(column_names["density"])
axes[0, 2].set_ylabel(column_names["actual_delivery_days"])
axes[0, 2].set_title(f"Relación entre {column_names['density']} y {column_names['actual_delivery_days']}")
axes[0, 2].set_xlim(0, df["density"].quantile(0.95))  # Limitar para mejor visualización
axes[0, 2].grid(True, alpha=0.3)

# 4. Cliente remoto vs no remoto
customer_remote_delivery = df.groupby("customer_remote")["actual_delivery_days"].mean()
axes[1, 0].bar(["No Remoto", "Remoto"], customer_remote_delivery.values, color="steelblue", edgecolor="black")
axes[1, 0].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[1, 0].set_title(f"{column_names['actual_delivery_days']} por {column_names['customer_remote']}")
axes[1, 0].grid(True, alpha=0.3, axis="y")

# 5. Compras en fin de semana vs entre semana
weekend_delivery = df.groupby("purchase_weekend")["actual_delivery_days"].mean()
axes[1, 1].bar(["Entre Semana", "Fin de Semana"], weekend_delivery.values, color="coral", edgecolor="black")
axes[1, 1].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[1, 1].set_title(f"{column_names['actual_delivery_days']} por {column_names['purchase_weekend']}")
axes[1, 1].grid(True, alpha=0.3, axis="y")

# 6. Compras en horario laboral vs fuera de horario
business_hours_delivery = df.groupby("purchase_business_hours")["actual_delivery_days"].mean()
axes[1, 2].bar(
    ["Fuera de Horario", "Horario Laboral"], business_hours_delivery.values, color="steelblue", edgecolor="black"
)
axes[1, 2].set_ylabel(f"{column_names['actual_delivery_days']} (promedio)")
axes[1, 2].set_title(f"{column_names['actual_delivery_days']} por {column_names['purchase_business_hours']}")
axes[1, 2].grid(True, alpha=0.3, axis="y")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Análisis de las nuevas características
#
# Las nuevas características muestran patrones interesantes:
# - **Categoría de distancia**: confirma que a mayor distancia, mayor tiempo de entrega, con incrementos claros entre categorías.
# - **Mismo estado**: las entregas dentro del mismo estado son significativamente más rápidas que las interestatales.
# - **Clientes remotos**: los clientes en regiones remotas (norte) tienen tiempos de entrega considerablemente más largos.
# - **Fin de semana**: la diferencia es mínima (≈0.1 días extra), el efecto es prácticamente marginal.
# - **Horario laboral**: diferencia casi nula (≈0.06 días), no se observa impacto operativo relevante.
#
# Un dato interesante es que la densidad del paquete (peso/volumen) no muestra una correlación fuerte con el tiempo de entrega, sugiriendo que el factor logístico principal es la distancia y ubicación, no las características físicas del paquete.
#
# ## Preparación del dataset para modelado
#
# Antes de entrenar un modelo, separamos los datos respetando la dimensión temporal para evitar _leakage_ (no entrenamos con información "del futuro"). Hacemos:
# - Ordenamos por `order_purchase_timestamp`.
# - Tomamos el **20% más reciente** como _test_ final.
# - Del 80% restante, reservamos el **15% más reciente** como _validación_ y el resto como _train_ para ajustar modelos.

# %%
# Ordenamos cronológicamente por la fecha de compra
df_sorted = df.sort_values("order_purchase_timestamp")

# Hacemos un corte 80/20 (train_val / test)
cutoff_test = int(len(df_sorted) * 0.8)
train_val = df_sorted.iloc[:cutoff_test]
test = df_sorted.iloc[cutoff_test:]

# Dentro de train_val, reservamos validación (último 15%)
cutoff_val = int(len(train_val) * 0.85)
train = train_val.iloc[:cutoff_val]
val = train_val.iloc[cutoff_val:]

print(f"""
Tamaño train: {len(train):,}
Tamaño val:   {len(val):,}
Tamaño test:  {len(test):,}
""")

# Separamos features/target (aún sin preprocesamiento)
target_col = "actual_delivery_days"
x_train, y_train = train.drop(columns=[target_col]), train[target_col]
x_val, y_val = val.drop(columns=[target_col]), val[target_col]
x_test, y_test = test.drop(columns=[target_col]), test[target_col]
# Out:
# Tamaño train: 65,264
# Tamaño val:   11,518
# Tamaño test:  19,196

# %% [markdown]
# Con esto tenemos tres conjuntos: `train` para ajustar, `val` para comparar hiperparámetros sin tocar `test`, y `test` como evaluación final.
#
# ## Primer modelo: random forest (baseline)
#
# Usamos un Random Forest como línea base rápida: maneja no linealidades, no requiere normalización y, con codificación _one-hot_ para las categorías, puede capturar interacciones simples. Evaluamos con MAE y RMSE en validación y test.

# %%
target_col = "actual_delivery_days"

# Definimos automáticamente columnas categóricas y numéricas (evitando fugas temporales)
drop_cols = {
    target_col,
    "order_id",
    "order_purchase_timestamp",
    "order_delivered_customer_date",
}
feature_cols = [c for c in df.columns if c not in drop_cols]

feature_df = df[feature_cols]
categorical_features = feature_df.select_dtypes(include=["object", "category"]).columns.tolist()
numeric_features = feature_df.select_dtypes(include=[np.number]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features),
        ("num", "passthrough", numeric_features),
    ],
    remainder="drop",
)

rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1,
)

model_rf = Pipeline(
    steps=[
        ("preprocess", preprocess),
        ("rf", rf),
    ]
)

model_rf.fit(x_train, y_train)

val_preds = model_rf.predict(x_val)
val_mae = mean_absolute_error(y_val, val_preds)
val_rmse = root_mean_squared_error(y_val, val_preds)
print(f"Validación | MAE={val_mae:.2f} días | RMSE={val_rmse:.2f} días")

test_preds = model_rf.predict(x_test)
test_mae = mean_absolute_error(y_test, test_preds)
test_rmse = root_mean_squared_error(y_test, test_preds)
print(f"Test | MAE={test_mae:.2f} días | RMSE={test_rmse:.2f} días")
# Out:
# Validación | MAE=4.64 días | RMSE=6.62 días
# Test | MAE=4.18 días | RMSE=5.55 días

# %% [markdown]
# Esto nos da una métrica inicial sin recurrir al conjunto de test antes de tiempo (solo para inspección final). Con estas métricas vemos que el desempeño en validación es razonable y mejora ligeramente en test, señal de que el período más reciente es algo más predecible y que el modelo captura patrones útiles sin signos claros de overfitting.
#
# Para comparar distribuciones de predicción vs. real, contrastamos histogramas:

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

for ax, y_true, y_pred, title in [
    (axes[0], y_val, val_preds, "Validación"),
    (axes[1], y_test, test_preds, "Test"),
]:
    ax.hist(y_true, bins=50, alpha=0.5, label="Real", color="steelblue", edgecolor="black")
    ax.hist(y_pred, bins=50, alpha=0.5, label="Predicción", color="coral", edgecolor="black")
    ax.set_xlabel("Entrega (días)")
    ax.set_ylabel("Frecuencia")
    ax.set_title(f"Distribución real vs predicha ({title})")
    ax.grid(True, alpha=0.3)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación:** las barras naranjas (predicción) siguen bastante bien a las azules (datos reales), compartiendo el pico principal alrededor de los 10 días. Las predicciones subestiman las entregas muy largas (casi no hay valores predichos por arriba de 25-30 días), pero esa cola es poco frecuente. Validación y test lucen casi iguales, lo que indica que el modelo se comporta de manera similar en ambos períodos.
#
# ## Optimización del modelo: hyperparameter tuning
#
# El modelo baseline Random Forest con parámetros por defecto nos dio resultados prometedores (MAE test ≈ 4.2 días). Ahora vamos a optimizarlo mediante búsqueda de hiperparámetros para ver hasta dónde podemos llevar su desempeño.
#
# ### Estrategia de tuning
#
# Usaremos `RandomizedSearchCV` en lugar de `GridSearchCV` porque:
# - **más eficiente:** evalúa un subconjunto aleatorio del espacio de hiperparámetros en lugar de todas las combinaciones.
# - **mejor exploración:** puede descubrir combinaciones que GridSearch no evaluaría.
# - **tiempo razonable:** con ~65k muestras de entrenamiento, GridSearch sería muy lento.
#
# Optimizaremos los siguientes hiperparámetros clave:
# - `n_estimators`: número de árboles (más árboles = mejor generalización hasta cierto punto)
# - `max_depth`: profundidad máxima de árboles (controla overfitting)
# - `min_samples_split`: mínimo de muestras para dividir un nodo (regularización)
# - `min_samples_leaf`: mínimo de muestras en hojas (regularización)
# - `max_features`: número de features a considerar en cada split (diversidad)
# - `bootstrap`: si usar muestreo con reemplazo o no

# %%
# Definimos el espacio de búsqueda
param_distributions_rf = {
    "rf__n_estimators": randint(300, 600),  # Más árboles para mejor generalización
    "rf__max_depth": [None, 40, 50],  # Mayor profundidad, evitamos regularización excesiva
    "rf__min_samples_split": randint(2, 10),  # Menos regularización
    "rf__min_samples_leaf": randint(1, 5),  # Menos regularización
    "rf__max_features": ["sqrt", "log2"],  # Sin None para evitar entrenamientos muy lentos
    "rf__bootstrap": [True, False],  # Muestreo
}

# Configuramos RandomizedSearchCV
random_search_rf = RandomizedSearchCV(
    estimator=model_rf,
    param_distributions=param_distributions_rf,
    n_iter=50,  # 50 combinaciones aleatorias
    scoring="neg_mean_absolute_error",  # Optimizamos MAE
    cv=3,  # 3-fold cross-validation
    verbose=2,
    random_state=42,
    n_jobs=-1,
)

start_time = time.time()
random_search_rf.fit(x_train, y_train)
elapsed_time = time.time() - start_time

print(f"""
Iniciando búsqueda de hiperparámetros...
Evaluando 50 combinaciones con 3-fold CV en {len(x_train):,} muestras
Esto puede tomar varios minutos...

✓ Búsqueda completada en {elapsed_time / 60:.1f} minutos

Mejores hiperparámetros encontrados:
""")

for param, value in random_search_rf.best_params_.items():
    print(f"  {param}: {value}")

print(f"\nMejor MAE en CV: {-random_search_rf.best_score_:.3f} días")
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=387; total time=  13.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=387; total time=  28.5s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=3, rf__n_estimators=593; total time=  30.2s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=387; total time=  31.1s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=3, rf__n_estimators=593; total time=  35.5s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=9, rf__n_estimators=488; total time=  38.3s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=9, rf__n_estimators=488; total time=  41.2s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=9, rf__n_estimators=488; total time=  43.7s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=3, rf__n_estimators=321; total time=  43.9s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=3, rf__n_estimators=321; total time=  35.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=3, rf__n_estimators=593; total time=  58.8s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=4, rf__n_estimators=469; total time=  32.9s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=4, rf__n_estimators=469; total time=  32.8s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=350; total time=  30.4s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=3, rf__n_estimators=321; total time=  41.6s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=4, rf__n_estimators=469; total time=  36.2s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=350; total time=  31.5s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=430; total time=  33.0s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=350; total time=  36.5s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=430; total time=  34.9s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=430; total time=  41.1s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=466; total time=  47.3s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=466; total time=  49.3s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=564; total time=  45.8s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=466; total time=  51.6s
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=564; total time=  53.7s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=349; total time=  25.1s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=563; total time=  51.3s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=564; total time=  59.6s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=563; total time=  52.4s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=349; total time=  23.6s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=5, rf__n_estimators=563; total time=  49.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=349; total time=  22.4s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=7, rf__n_estimators=405; total time=  29.6s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=7, rf__n_estimators=405; total time=  25.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=551; total time=  25.9s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=3, rf__n_estimators=517; total time=  45.4s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=7, rf__n_estimators=405; total time=  41.1s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=569; total time=  44.8s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=3, rf__n_estimators=517; total time=  54.7s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=551; total time=  36.9s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=3, rf__n_estimators=517; total time=  54.1s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=551; total time=  38.2s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=9, rf__n_estimators=536; total time=  35.2s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=569; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=569; total time=  59.0s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=9, rf__n_estimators=536; total time=  41.3s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=9, rf__n_estimators=536; total time=  38.2s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=3, rf__n_estimators=516; total time=  42.4s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=8, rf__n_estimators=364; total time=  41.7s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=435; total time=  29.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=435; total time=  36.0s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=3, rf__n_estimators=516; total time=  54.7s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=2, rf__n_estimators=435; total time=  32.4s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=8, rf__n_estimators=364; total time=  49.6s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=8, rf__n_estimators=364; total time=  51.7s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=3, rf__n_estimators=516; total time=  55.5s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=2, rf__n_estimators=462; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=361; total time=  30.2s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=2, rf__n_estimators=462; total time=  55.9s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=3, rf__n_estimators=530; total time=  53.8s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=2, rf__n_estimators=462; total time=  58.2s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=3, rf__n_estimators=530; total time=  54.6s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=3, rf__n_estimators=530; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=2, rf__n_estimators=567; total time=  56.6s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=2, rf__n_estimators=567; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=2, rf__n_estimators=567; total time=  59.5s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=361; total time=  32.6s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=361; total time=  33.6s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=6, rf__n_estimators=430; total time=  35.3s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=582; total time=  27.0s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=6, rf__n_estimators=430; total time=  43.0s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=6, rf__n_estimators=430; total time=  40.4s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=582; total time=  35.1s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=9, rf__n_estimators=513; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=9, rf__n_estimators=513; total time=  58.9s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=9, rf__n_estimators=513; total time= 1.0min
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=582; total time=  36.0s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=478; total time=  47.5s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=6, rf__n_estimators=395; total time=  30.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=6, rf__n_estimators=395; total time=  30.9s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=6, rf__n_estimators=395; total time=  32.1s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=478; total time=  47.1s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=478; total time=  46.0s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=6, rf__n_estimators=459; total time=  33.8s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=6, rf__n_estimators=459; total time=  35.6s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=365; total time=  27.1s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=536; total time=  57.3s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=365; total time=  28.4s
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=6, rf__n_estimators=459; total time=  37.1s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=536; total time= 1.1min
# [CV] END rf__bootstrap=True, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=365; total time=  31.2s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=536; total time= 1.1min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=6, rf__n_estimators=433; total time=  42.9s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=6, rf__n_estimators=433; total time=  41.2s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=9, rf__n_estimators=530; total time=  42.0s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=6, rf__n_estimators=433; total time=  51.7s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=9, rf__n_estimators=530; total time=  51.2s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=9, rf__n_estimators=530; total time=  52.0s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=497; total time=  52.2s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=420; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=420; total time= 1.1min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=420; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=497; total time=  52.7s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=8, rf__n_estimators=459; total time=  24.9s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=8, rf__n_estimators=459; total time=  22.4s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=497; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=6, rf__n_estimators=524; total time=  54.3s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=4, rf__min_samples_split=8, rf__n_estimators=459; total time=  28.1s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=7, rf__n_estimators=351; total time=  39.8s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=7, rf__n_estimators=351; total time=  42.0s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=6, rf__n_estimators=524; total time= 1.2min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=7, rf__n_estimators=351; total time=  43.9s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=6, rf__n_estimators=524; total time= 1.2min
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=4, rf__n_estimators=412; total time=  47.4s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=4, rf__n_estimators=412; total time=  46.4s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=412; total time=  37.2s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=412; total time=  35.0s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=4, rf__n_estimators=412; total time=  46.6s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=412; total time=  31.1s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=352; total time=  28.3s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=523; total time=  43.4s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=352; total time=  35.4s
# [CV] END rf__bootstrap=True, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=2, rf__min_samples_split=3, rf__n_estimators=352; total time=  33.0s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=523; total time=  51.9s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=8, rf__n_estimators=523; total time=  53.2s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=9, rf__n_estimators=546; total time=  47.9s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=9, rf__n_estimators=546; total time=  56.3s
# [CV] END rf__bootstrap=False, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=9, rf__n_estimators=546; total time= 1.1min
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=4, rf__n_estimators=554; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=4, rf__n_estimators=554; total time= 1.1min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=7, rf__n_estimators=539; total time=  54.9s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=7, rf__n_estimators=539; total time= 1.0min
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=4, rf__n_estimators=554; total time= 1.1min
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=log2, rf__min_samples_leaf=2, rf__min_samples_split=7, rf__n_estimators=539; total time=  55.4s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=4, rf__n_estimators=558; total time=  56.7s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=3, rf__n_estimators=446; total time=  37.7s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=4, rf__n_estimators=558; total time=  58.0s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=3, rf__n_estimators=446; total time=  47.3s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=450; total time=  35.0s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=3, rf__n_estimators=446; total time=  46.8s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=450; total time=  39.2s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=4, rf__n_estimators=450; total time=  31.7s
# [CV] END rf__bootstrap=False, rf__max_depth=None, rf__max_features=sqrt, rf__min_samples_leaf=4, rf__min_samples_split=4, rf__n_estimators=558; total time= 1.2min
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=427; total time=  49.9s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=427; total time=  52.1s
# [CV] END rf__bootstrap=False, rf__max_depth=50, rf__max_features=log2, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=427; total time=  53.3s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=551; total time=  28.5s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=551; total time=  26.9s
# [CV] END rf__bootstrap=True, rf__max_depth=40, rf__max_features=log2, rf__min_samples_leaf=3, rf__min_samples_split=8, rf__n_estimators=551; total time=  13.6s
#
# Iniciando búsqueda de hiperparámetros...
# Evaluando 50 combinaciones con 3-fold CV en 65,264 muestras
# Esto puede tomar varios minutos...
#
# ✓ Búsqueda completada en 11.6 minutos
#
# Mejores hiperparámetros encontrados:
#
#   rf__bootstrap: True
#   rf__max_depth: 40
#   rf__max_features: log2
#   rf__min_samples_leaf: 4
#   rf__min_samples_split: 8
#   rf__n_estimators: 459
#
# Mejor MAE en CV: 7.418 días

# %%
# Evaluamos el modelo optimizado en validación y test
model_rf_opt = random_search_rf.best_estimator_

val_preds_rf_opt = model_rf_opt.predict(x_val)
val_mae_opt = mean_absolute_error(y_val, val_preds_rf_opt)
val_rmse_opt = root_mean_squared_error(y_val, val_preds_rf_opt)

test_preds_rf_opt = model_rf_opt.predict(x_test)
test_mae_opt = mean_absolute_error(y_test, test_preds_rf_opt)
test_rmse_opt = root_mean_squared_error(y_test, test_preds_rf_opt)

print(f"""
{"=" * 70}
COMPARACIÓN – modelo baseline vs optimizado
{"=" * 70}

MODELO BASELINE
  Validación | MAE={val_mae:.3f} días | RMSE={val_rmse:.3f} días
  Test       | MAE={test_mae:.3f} días | RMSE={test_rmse:.3f} días

MODELO OPTIMIZADO
  Validación | MAE={val_mae_opt:.3f} días | RMSE={val_rmse_opt:.3f} días
  Test       | MAE={test_mae_opt:.3f} días | RMSE={test_rmse_opt:.3f} días

MEJORA
  Validación | {((val_mae - val_mae_opt) / val_mae * 100):+.2f}% (MAE)
  Test       | {((test_mae - test_mae_opt) / test_mae * 100):+.2f}% (MAE)
{"=" * 70}
""")
# Out:
# ======================================================================
# COMPARACIÓN – modelo baseline vs optimizado
# ======================================================================
#
# MODELO BASELINE
#   Validación | MAE=4.639 días | RMSE=6.619 días
#   Test       | MAE=4.180 días | RMSE=5.545 días
#
# MODELO OPTIMIZADO
#   Validación | MAE=5.107 días | RMSE=6.875 días
#   Test       | MAE=4.625 días | RMSE=5.901 días
#
# MEJORA
#   Validación | -10.08% (MAE)
#   Test       | -10.64% (MAE)
# ======================================================================

# %% [markdown]
# ### Conclusión: ¿Por qué empeora con tuning?
#
# El tuning de hiperparámetros **empeoró** el modelo baseline de Random Forest (4.625 días vs 4.180 días en test, -10.64%). Este resultado contraintuitivo revela un patrón importante:
#
# **Raíz del problema:** la búsqueda de hiperparámetros encontró una combinación de parámetros que **regulariza demasiado** el modelo:
# - Parámetros como `min_samples_split` y `min_samples_leaf` más altos restringen la capacidad del modelo
# - El baseline con parámetros por defecto ya tenía el balance correcto entre sesgo y varianza
# - Esto causó **underfitting**: el modelo no pudo aprender los patrones geográficos complejos
#
# **Lección clave:** los parámetros por defecto de Random Forest ya están bien calibrados para la mayoría de problemas. La búsqueda aleatoria encontró configuraciones más restrictivas que empeoraron el desempeño.
#
# **Conclusión:** para este problema, los parámetros por defecto de Random Forest funcionaban mejor. El tuning no siempre ayuda; a veces el baseline es el mejor modelo.
#
# Por esto, vamos a probar XGBoost con parámetros por defecto, que puede capturar patrones más complejos.
#
# ## Modelo alternativo con XGBoost
#
# Random Forest no mejoró con tuning, así que probamos XGBoost. Este algoritmo usa boosting (los árboles aprenden de los errores de los anteriores) en lugar de bagging (árboles independientes como Random Forest), lo que puede capturar patrones más complejos.
#
# ### Modelo baseline de XGBoost
#
# Primero probamos XGBoost con parámetros por defecto:

# %%
# Creamos pipeline con XGBoost
model_xgb = Pipeline(
    [
        ("preprocess", preprocess),
        (
            "xgb",
            XGBRegressor(
                random_state=42,
                n_jobs=-1,
                n_estimators=200,  # Mismo que RF baseline para comparación justa
            ),
        ),
    ]
)

# Entrenamos
model_xgb.fit(x_train, y_train)

# Predicciones
val_preds_xgb = model_xgb.predict(x_val)
val_mae_xgb = mean_absolute_error(y_val, val_preds_xgb)
val_rmse_xgb = root_mean_squared_error(y_val, val_preds_xgb)

test_preds_xgb = model_xgb.predict(x_test)
test_mae_xgb = mean_absolute_error(y_test, test_preds_xgb)
test_rmse_xgb = root_mean_squared_error(y_test, test_preds_xgb)

print(f"""
{"=" * 70}
COMPARACIÓN – Random Forest vs XGBoost
{"=" * 70}

RANDOM FOREST BASELINE
  Validación | MAE={val_mae:.3f} días | RMSE={val_rmse:.3f} días
  Test       | MAE={test_mae:.3f} días | RMSE={test_rmse:.3f} días

XGBOOST BASELINE
  Validación | MAE={val_mae_xgb:.3f} días | RMSE={val_rmse_xgb:.3f} días
  Test       | MAE={test_mae_xgb:.3f} días | RMSE={test_rmse_xgb:.3f} días

DIFERENCIA (XGB vs RF)
  Validación | {((val_mae - val_mae_xgb) / val_mae * 100):+.2f}% (MAE)
  Test       | {((test_mae - test_mae_xgb) / test_mae * 100):+.2f}% (MAE)
{"=" * 70}
""")
# Out:
# ======================================================================
# COMPARACIÓN – Random Forest vs XGBoost
# ======================================================================
#
# RANDOM FOREST BASELINE
#   Validación | MAE=4.639 días | RMSE=6.619 días
#   Test       | MAE=4.180 días | RMSE=5.545 días
#
# XGBOOST BASELINE
#   Validación | MAE=4.455 días | RMSE=6.015 días
#   Test       | MAE=3.851 días | RMSE=5.048 días
#
# DIFERENCIA (XGB vs RF)
#   Validación | +3.98% (MAE)
#   Test       | +7.86% (MAE)
# ======================================================================

# %% [markdown]
# ### Visualización comparativa

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Comparamos en test
y_true = y_test

# 1. Histograma de predicciones
ax = axes[0, 0]
ax.hist(y_true, bins=50, alpha=0.3, label="Real", color="gray", edgecolor="black")
ax.hist(test_preds, bins=50, alpha=0.5, label="Random Forest", color="steelblue", edgecolor="black")
ax.hist(test_preds_xgb, bins=50, alpha=0.5, label="XGBoost", color="green", edgecolor="black")
ax.set_xlabel("Días de entrega")
ax.set_ylabel("Frecuencia")
ax.set_title("Distribución de predicciones (Test)")
ax.legend()
ax.grid(True, alpha=0.3)

# 2. Scatter: real vs predicho
ax = axes[0, 1]
ax.scatter(y_true, test_preds, alpha=0.3, s=10, label="Random Forest", color="steelblue")
ax.scatter(y_true, test_preds_xgb, alpha=0.3, s=10, label="XGBoost", color="green")

max_val = max(y_true.max(), test_preds.max(), test_preds_xgb.max())
ax.plot([0, max_val], [0, max_val], "r--", linewidth=2, label="Predicción perfecta")

ax.set_xlabel("Días reales")
ax.set_ylabel("Días predichos")
ax.set_title("Real vs Predicho (Test)")
ax.legend()
ax.grid(True, alpha=0.3)

# 3. Residuos - Random Forest
ax = axes[1, 0]
residuals_rf = y_test - test_preds
ax.hist(residuals_rf, bins=50, color="steelblue", edgecolor="black", alpha=0.7)
ax.axvline(x=0, color="red", linestyle="--", linewidth=2, label="Error = 0")
ax.axvline(
    x=residuals_rf.mean(), color="orange", linestyle="--", linewidth=2, label=f"Media: {residuals_rf.mean():.2f} días"
)
ax.set_xlabel("Residuo (días)")
ax.set_ylabel("Frecuencia")
ax.set_title("Residuos - Random Forest")
ax.legend()
ax.grid(True, alpha=0.3)

# 4. Residuos - XGBoost
ax = axes[1, 1]
residuals_xgb = y_test - test_preds_xgb
ax.hist(residuals_xgb, bins=50, color="green", edgecolor="black", alpha=0.7)
ax.axvline(x=0, color="red", linestyle="--", linewidth=2, label="Error = 0")
ax.axvline(
    x=residuals_xgb.mean(), color="orange", linestyle="--", linewidth=2, label=f"Media: {residuals_xgb.mean():.2f} días"
)
ax.set_xlabel("Residuo (días)")
ax.set_ylabel("Frecuencia")
ax.set_title("Residuos - XGBoost")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Comparación de residuos
print(f"""
Comparación de residuos (Test):

RANDOM FOREST:
  Media:      {residuals_rf.mean():.3f} días
  Mediana:    {residuals_rf.median():.3f} días
  Desv. std:  {residuals_rf.std():.3f} días

XGBOOST:
  Media:      {residuals_xgb.mean():.3f} días
  Mediana:    {residuals_xgb.median():.3f} días
  Desv. std:  {residuals_xgb.std():.3f} días

(Ideal: media ≈ 0, desviación baja)
""")
# Out:
# Comparación de residuos (Test):
#
# RANDOM FOREST:
#   Media:      -2.459 días
#   Mediana:    -2.808 días
#   Desv. std:  4.970 días
#
# XGBOOST:
#   Media:      -2.016 días
#   Mediana:    -2.365 días
#   Desv. std:  4.627 días
#
# (Ideal: media ≈ 0, desviación baja)

# %% [markdown]
# ### Conclusión
#
# XGBoost es mucho mejor que Random Forest para este problema. Con parámetros por defecto, XGBoost obtuvo un MAE de 3.851 días en test, mientras que Random Forest obtuvo 4.180 días. Eso es una mejora de 7.86%.
#
# Además, XGBoost tiene menos sesgo. Sus residuos tienen media de -2.016 días (vs -2.459 de Random Forest), lo que significa que sobreestima menos los tiempos de entrega. También las predicciones son más consistentes: la desviación estándar es 4.627 vs 4.970 de Random Forest.
#
# Por esto, XGBoost pasa a ser nuestro nuevo benchmark a vencer antes de probar LightGBM y CatBoost.
#
# ## Optimización de XGBoost
#
# Aunque XGBoost ya es mejor que Random Forest, vamos a optimizar sus hiperparámetros para ver si podemos mejorar aún más.
#
# ### Tuning de hiperparámetros

# %%
# Definimos el espacio de búsqueda para XGBoost
param_distributions_xgb = {
    "xgb__n_estimators": randint(100, 500),
    "xgb__max_depth": randint(3, 10),
    "xgb__learning_rate": uniform(0.01, 0.3),
    "xgb__subsample": uniform(0.5, 0.5),
    "xgb__colsample_bytree": uniform(0.5, 0.5),
    "xgb__min_child_weight": randint(1, 5),
}

# Configuramos RandomizedSearchCV
random_search_xgb = RandomizedSearchCV(
    estimator=Pipeline([("preprocess", preprocess), ("xgb", XGBRegressor(random_state=42, n_jobs=-1))]),
    param_distributions=param_distributions_xgb,
    n_iter=50,
    scoring="neg_mean_absolute_error",
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=-1,
)

start_time = time.time()
random_search_xgb.fit(x_train, y_train)
elapsed_time = time.time() - start_time

print(f"""
Tuning de XGBoost completado

✓ Tiempo: {elapsed_time / 60:.1f} minutos

Mejores hiperparámetros encontrados:
""")

for param, value in random_search_xgb.best_params_.items():
    print(f"  {param}: {value}")

print(f"\nMejor MAE en CV: {-random_search_xgb.best_score_:.3f} días")
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END xgb__colsample_bytree=0.6872700594236812, xgb__learning_rate=0.2952142919229748, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=288, xgb__subsample=0.7984250789732434; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.6872700594236812, xgb__learning_rate=0.2952142919229748, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=288, xgb__subsample=0.7984250789732434; total time=   2.0s
# [CV] END xgb__colsample_bytree=0.6872700594236812, xgb__learning_rate=0.2952142919229748, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=288, xgb__subsample=0.7984250789732434; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.9961057796456088, xgb__learning_rate=0.19524445288831496, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=352, xgb__subsample=0.7159725093210578; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.7229163764267956, xgb__learning_rate=0.039992474745400866, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=472, xgb__subsample=0.8005575058716043; total time=   2.7s
# [CV] END xgb__colsample_bytree=0.8540362888980227, xgb__learning_rate=0.016175348288740735, xgb__max_depth=4, xgb__min_child_weight=4, xgb__n_estimators=393, xgb__subsample=0.5003893829205072; total time=   2.9s
# [CV] END xgb__colsample_bytree=0.8540362888980227, xgb__learning_rate=0.016175348288740735, xgb__max_depth=4, xgb__min_child_weight=4, xgb__n_estimators=393, xgb__subsample=0.5003893829205072; total time=   2.6s
# [CV] END xgb__colsample_bytree=0.8540362888980227, xgb__learning_rate=0.016175348288740735, xgb__max_depth=4, xgb__min_child_weight=4, xgb__n_estimators=393, xgb__subsample=0.5003893829205072; total time=   3.0s
# [CV] END xgb__colsample_bytree=0.7229163764267956, xgb__learning_rate=0.039992474745400866, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=472, xgb__subsample=0.8005575058716043; total time=   3.5s
# [CV] END xgb__colsample_bytree=0.7229163764267956, xgb__learning_rate=0.039992474745400866, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=472, xgb__subsample=0.8005575058716043; total time=   3.6s
# [CV] END xgb__colsample_bytree=0.645614570099021, xgb__learning_rate=0.19355586841671385, xgb__max_depth=4, xgb__min_child_weight=4, xgb__n_estimators=287, xgb__subsample=0.6831809216468459; total time=   1.8s
# [CV] END xgb__colsample_bytree=0.9961057796456088, xgb__learning_rate=0.19524445288831496, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=352, xgb__subsample=0.7159725093210578; total time=   2.0s
# [CV] END xgb__colsample_bytree=0.9961057796456088, xgb__learning_rate=0.19524445288831496, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=352, xgb__subsample=0.7159725093210578; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.645614570099021, xgb__learning_rate=0.19355586841671385, xgb__max_depth=4, xgb__min_child_weight=4, xgb__n_estimators=287, xgb__subsample=0.6831809216468459; total time=   1.3s
# [CV] END xgb__colsample_bytree=0.728034992108518, xgb__learning_rate=0.24555278841790407, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=154, xgb__subsample=0.9916154429033941; total time=   1.2s
# [CV] END xgb__colsample_bytree=0.728034992108518, xgb__learning_rate=0.24555278841790407, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=154, xgb__subsample=0.9916154429033941; total time=   1.0s
# [CV] END xgb__colsample_bytree=0.728034992108518, xgb__learning_rate=0.24555278841790407, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=154, xgb__subsample=0.9916154429033941; total time=   1.2s
# [CV] END xgb__colsample_bytree=0.645614570099021, xgb__learning_rate=0.19355586841671385, xgb__max_depth=4, xgb__min_child_weight=4, xgb__n_estimators=287, xgb__subsample=0.6831809216468459; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.9744427686266666, xgb__learning_rate=0.2996896099223678, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=364, xgb__subsample=0.5079831261101071; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.9744427686266666, xgb__learning_rate=0.2996896099223678, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=364, xgb__subsample=0.5079831261101071; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.9744427686266666, xgb__learning_rate=0.2996896099223678, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=364, xgb__subsample=0.5079831261101071; total time=   2.3s
# [CV] END xgb__colsample_bytree=0.6154469128110744, xgb__learning_rate=0.0823076398078035, xgb__max_depth=6, xgb__min_child_weight=3, xgb__n_estimators=363, xgb__subsample=0.5171942605576092; total time=   2.5s
# [CV] END xgb__colsample_bytree=0.6154469128110744, xgb__learning_rate=0.0823076398078035, xgb__max_depth=6, xgb__min_child_weight=3, xgb__n_estimators=363, xgb__subsample=0.5171942605576092; total time=   2.8s
# [CV] END xgb__colsample_bytree=0.6154469128110744, xgb__learning_rate=0.0823076398078035, xgb__max_depth=6, xgb__min_child_weight=3, xgb__n_estimators=363, xgb__subsample=0.5171942605576092; total time=   3.2s
# [CV] END xgb__colsample_bytree=0.7838501639099957, xgb__learning_rate=0.019393987736667576, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=143, xgb__subsample=0.9697494707820946; total time=   1.1s
# [CV] END xgb__colsample_bytree=0.7838501639099957, xgb__learning_rate=0.019393987736667576, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=143, xgb__subsample=0.9697494707820946; total time=   0.9s
# [CV] END xgb__colsample_bytree=0.7838501639099957, xgb__learning_rate=0.019393987736667576, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=143, xgb__subsample=0.9697494707820946; total time=   1.0s
# [CV] END xgb__colsample_bytree=0.954660201039391, xgb__learning_rate=0.08763399448000507, xgb__max_depth=6, xgb__min_child_weight=2, xgb__n_estimators=489, xgb__subsample=0.6039708314340944; total time=   4.5s
# [CV] END xgb__colsample_bytree=0.954660201039391, xgb__learning_rate=0.08763399448000507, xgb__max_depth=6, xgb__min_child_weight=2, xgb__n_estimators=489, xgb__subsample=0.6039708314340944; total time=   4.4s
# [CV] END xgb__colsample_bytree=0.954660201039391, xgb__learning_rate=0.08763399448000507, xgb__max_depth=6, xgb__min_child_weight=2, xgb__n_estimators=489, xgb__subsample=0.6039708314340944; total time=   4.4s
# [CV] END xgb__colsample_bytree=0.73338144662399, xgb__learning_rate=0.26798212202089616, xgb__max_depth=9, xgb__min_child_weight=1, xgb__n_estimators=428, xgb__subsample=0.5325257964926398; total time=   8.4s
# [CV] END xgb__colsample_bytree=0.73338144662399, xgb__learning_rate=0.26798212202089616, xgb__max_depth=9, xgb__min_child_weight=1, xgb__n_estimators=428, xgb__subsample=0.5325257964926398; total time=   8.1s
# [CV] END xgb__colsample_bytree=0.9474136752138245, xgb__learning_rate=0.18936999364332555, xgb__max_depth=9, xgb__min_child_weight=4, xgb__n_estimators=314, xgb__subsample=0.7604171300129119; total time=   4.5s
# [CV] END xgb__colsample_bytree=0.73338144662399, xgb__learning_rate=0.26798212202089616, xgb__max_depth=9, xgb__min_child_weight=1, xgb__n_estimators=428, xgb__subsample=0.5325257964926398; total time=   8.7s
# [CV] END xgb__colsample_bytree=0.6783766633467947, xgb__learning_rate=0.09428035290621423, xgb__max_depth=6, xgb__min_child_weight=1, xgb__n_estimators=140, xgb__subsample=0.6481367528520412; total time=   1.5s
# [CV] END xgb__colsample_bytree=0.9805860121746746, xgb__learning_rate=0.2633601546034454, xgb__max_depth=7, xgb__min_child_weight=2, xgb__n_estimators=466, xgb__subsample=0.9143687545759647; total time=   4.3s
# [CV] END xgb__colsample_bytree=0.9474136752138245, xgb__learning_rate=0.18936999364332555, xgb__max_depth=9, xgb__min_child_weight=4, xgb__n_estimators=314, xgb__subsample=0.7604171300129119; total time=   5.7s
# [CV] END xgb__colsample_bytree=0.6783766633467947, xgb__learning_rate=0.09428035290621423, xgb__max_depth=6, xgb__min_child_weight=1, xgb__n_estimators=140, xgb__subsample=0.6481367528520412; total time=   1.3s
# [CV] END xgb__colsample_bytree=0.6783766633467947, xgb__learning_rate=0.09428035290621423, xgb__max_depth=6, xgb__min_child_weight=1, xgb__n_estimators=140, xgb__subsample=0.6481367528520412; total time=   1.5s
# [CV] END xgb__colsample_bytree=0.9474136752138245, xgb__learning_rate=0.18936999364332555, xgb__max_depth=9, xgb__min_child_weight=4, xgb__n_estimators=314, xgb__subsample=0.7604171300129119; total time=   5.9s
# [CV] END xgb__colsample_bytree=0.5826334695315012, xgb__learning_rate=0.01469092202235818, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=228, xgb__subsample=0.5993578407670862; total time=   1.3s
# [CV] END xgb__colsample_bytree=0.5826334695315012, xgb__learning_rate=0.01469092202235818, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=228, xgb__subsample=0.5993578407670862; total time=   1.5s
# [CV] END xgb__colsample_bytree=0.5826334695315012, xgb__learning_rate=0.01469092202235818, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=228, xgb__subsample=0.5993578407670862; total time=   1.6s
# [CV] END xgb__colsample_bytree=0.5027610585618012, xgb__learning_rate=0.25463842853645025, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=262, xgb__subsample=0.8950877702656028; total time=   1.3s
# [CV] END xgb__colsample_bytree=0.8029799873905057, xgb__learning_rate=0.2878902635540047, xgb__max_depth=4, xgb__min_child_weight=1, xgb__n_estimators=127, xgb__subsample=0.9315517129377968; total time=   0.9s
# [CV] END xgb__colsample_bytree=0.8029799873905057, xgb__learning_rate=0.2878902635540047, xgb__max_depth=4, xgb__min_child_weight=1, xgb__n_estimators=127, xgb__subsample=0.9315517129377968; total time=   1.0s
# [CV] END xgb__colsample_bytree=0.9805860121746746, xgb__learning_rate=0.2633601546034454, xgb__max_depth=7, xgb__min_child_weight=2, xgb__n_estimators=466, xgb__subsample=0.9143687545759647; total time=   5.5s
# [CV] END xgb__colsample_bytree=0.5027610585618012, xgb__learning_rate=0.25463842853645025, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=262, xgb__subsample=0.8950877702656028; total time=   1.3s
# [CV] END xgb__colsample_bytree=0.8029799873905057, xgb__learning_rate=0.2878902635540047, xgb__max_depth=4, xgb__min_child_weight=1, xgb__n_estimators=127, xgb__subsample=0.9315517129377968; total time=   0.7s
# [CV] END xgb__colsample_bytree=0.5027610585618012, xgb__learning_rate=0.25463842853645025, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=262, xgb__subsample=0.8950877702656028; total time=   1.6s
# [CV] END xgb__colsample_bytree=0.9805860121746746, xgb__learning_rate=0.2633601546034454, xgb__max_depth=7, xgb__min_child_weight=2, xgb__n_estimators=466, xgb__subsample=0.9143687545759647; total time=   5.1s
# [CV] END xgb__colsample_bytree=0.811649063413779, xgb__learning_rate=0.10926940745579475, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=161, xgb__subsample=0.6625916610133735; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.8566223936114975, xgb__learning_rate=0.23823551458506922, xgb__max_depth=4, xgb__min_child_weight=3, xgb__n_estimators=354, xgb__subsample=0.6280341613806619; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.811649063413779, xgb__learning_rate=0.10926940745579475, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=161, xgb__subsample=0.6625916610133735; total time=   3.0s
# [CV] END xgb__colsample_bytree=0.864803089169032, xgb__learning_rate=0.20126724140656393, xgb__max_depth=5, xgb__min_child_weight=3, xgb__n_estimators=326, xgb__subsample=0.5597971229691509; total time=   2.6s
# [CV] END xgb__colsample_bytree=0.811649063413779, xgb__learning_rate=0.10926940745579475, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=161, xgb__subsample=0.6625916610133735; total time=   2.9s
# [CV] END xgb__colsample_bytree=0.8566223936114975, xgb__learning_rate=0.23823551458506922, xgb__max_depth=4, xgb__min_child_weight=3, xgb__n_estimators=354, xgb__subsample=0.6280341613806619; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.864803089169032, xgb__learning_rate=0.20126724140656393, xgb__max_depth=5, xgb__min_child_weight=3, xgb__n_estimators=326, xgb__subsample=0.5597971229691509; total time=   2.5s
# [CV] END xgb__colsample_bytree=0.864803089169032, xgb__learning_rate=0.20126724140656393, xgb__max_depth=5, xgb__min_child_weight=3, xgb__n_estimators=326, xgb__subsample=0.5597971229691509; total time=   2.7s
# [CV] END xgb__colsample_bytree=0.8566223936114975, xgb__learning_rate=0.23823551458506922, xgb__max_depth=4, xgb__min_child_weight=3, xgb__n_estimators=354, xgb__subsample=0.6280341613806619; total time=   2.3s
# [CV] END xgb__colsample_bytree=0.5157145928433671, xgb__learning_rate=0.20092312337913412, xgb__max_depth=6, xgb__min_child_weight=1, xgb__n_estimators=195, xgb__subsample=0.8477580432130638; total time=   1.7s
# [CV] END xgb__colsample_bytree=0.5157145928433671, xgb__learning_rate=0.20092312337913412, xgb__max_depth=6, xgb__min_child_weight=1, xgb__n_estimators=195, xgb__subsample=0.8477580432130638; total time=   1.8s
# [CV] END xgb__colsample_bytree=0.5157145928433671, xgb__learning_rate=0.20092312337913412, xgb__max_depth=6, xgb__min_child_weight=1, xgb__n_estimators=195, xgb__subsample=0.8477580432130638; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.5202167947692157, xgb__learning_rate=0.22319886690573623, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=479, xgb__subsample=0.5539457134966522; total time=   3.1s
# [CV] END xgb__colsample_bytree=0.5202167947692157, xgb__learning_rate=0.22319886690573623, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=479, xgb__subsample=0.5539457134966522; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.5696657272029378, xgb__learning_rate=0.1913252137833452, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=128, xgb__subsample=0.6143990827458112; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.5696657272029378, xgb__learning_rate=0.1913252137833452, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=128, xgb__subsample=0.6143990827458112; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.5696657272029378, xgb__learning_rate=0.1913252137833452, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=128, xgb__subsample=0.6143990827458112; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.5202167947692157, xgb__learning_rate=0.22319886690573623, xgb__max_depth=4, xgb__min_child_weight=2, xgb__n_estimators=479, xgb__subsample=0.5539457134966522; total time=   2.7s
# [CV] END xgb__colsample_bytree=0.5384899549143964, xgb__learning_rate=0.0969254358741304, xgb__max_depth=8, xgb__min_child_weight=4, xgb__n_estimators=165, xgb__subsample=0.8121770240668966; total time=   2.3s
# [CV] END xgb__colsample_bytree=0.647816842918857, xgb__learning_rate=0.041648277949081186, xgb__max_depth=6, xgb__min_child_weight=4, xgb__n_estimators=207, xgb__subsample=0.5932850294430179; total time=   1.5s
# [CV] END xgb__colsample_bytree=0.5384899549143964, xgb__learning_rate=0.0969254358741304, xgb__max_depth=8, xgb__min_child_weight=4, xgb__n_estimators=165, xgb__subsample=0.8121770240668966; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.5384899549143964, xgb__learning_rate=0.0969254358741304, xgb__max_depth=8, xgb__min_child_weight=4, xgb__n_estimators=165, xgb__subsample=0.8121770240668966; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.647816842918857, xgb__learning_rate=0.041648277949081186, xgb__max_depth=6, xgb__min_child_weight=4, xgb__n_estimators=207, xgb__subsample=0.5932850294430179; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.647816842918857, xgb__learning_rate=0.041648277949081186, xgb__max_depth=6, xgb__min_child_weight=4, xgb__n_estimators=207, xgb__subsample=0.5932850294430179; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.9534142207728771, xgb__learning_rate=0.09163967481539059, xgb__max_depth=5, xgb__min_child_weight=2, xgb__n_estimators=220, xgb__subsample=0.9090073829612466; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.9534142207728771, xgb__learning_rate=0.09163967481539059, xgb__max_depth=5, xgb__min_child_weight=2, xgb__n_estimators=220, xgb__subsample=0.9090073829612466; total time=   2.0s
# [CV] END xgb__colsample_bytree=0.9462794992449889, xgb__learning_rate=0.17180267257469523, xgb__max_depth=4, xgb__min_child_weight=3, xgb__n_estimators=447, xgb__subsample=0.6781489190384875; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.9462794992449889, xgb__learning_rate=0.17180267257469523, xgb__max_depth=4, xgb__min_child_weight=3, xgb__n_estimators=447, xgb__subsample=0.6781489190384875; total time=   2.9s
# [CV] END xgb__colsample_bytree=0.9534142207728771, xgb__learning_rate=0.09163967481539059, xgb__max_depth=5, xgb__min_child_weight=2, xgb__n_estimators=220, xgb__subsample=0.9090073829612466; total time=   1.4s
# [CV] END xgb__colsample_bytree=0.9462794992449889, xgb__learning_rate=0.17180267257469523, xgb__max_depth=4, xgb__min_child_weight=3, xgb__n_estimators=447, xgb__subsample=0.6781489190384875; total time=   3.0s
# [CV] END xgb__colsample_bytree=0.7790510010086706, xgb__learning_rate=0.13115085131741225, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=151, xgb__subsample=0.6234380314193007; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.7790510010086706, xgb__learning_rate=0.13115085131741225, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=151, xgb__subsample=0.6234380314193007; total time=   1.8s
# [CV] END xgb__colsample_bytree=0.9303652916281717, xgb__learning_rate=0.01208563915935721, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=417, xgb__subsample=0.6110539052353652; total time=   3.4s
# [CV] END xgb__colsample_bytree=0.9303652916281717, xgb__learning_rate=0.01208563915935721, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=417, xgb__subsample=0.6110539052353652; total time=   3.7s
# [CV] END xgb__colsample_bytree=0.9303652916281717, xgb__learning_rate=0.01208563915935721, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=417, xgb__subsample=0.6110539052353652; total time=   3.6s
# [CV] END xgb__colsample_bytree=0.7790510010086706, xgb__learning_rate=0.13115085131741225, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=151, xgb__subsample=0.6234380314193007; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.8481521364198942, xgb__learning_rate=0.2236811769773326, xgb__max_depth=7, xgb__min_child_weight=1, xgb__n_estimators=180, xgb__subsample=0.6333905071376424; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.8481521364198942, xgb__learning_rate=0.2236811769773326, xgb__max_depth=7, xgb__min_child_weight=1, xgb__n_estimators=180, xgb__subsample=0.6333905071376424; total time=   1.7s
# [CV] END xgb__colsample_bytree=0.8481521364198942, xgb__learning_rate=0.2236811769773326, xgb__max_depth=7, xgb__min_child_weight=1, xgb__n_estimators=180, xgb__subsample=0.6333905071376424; total time=   1.8s
# [CV] END xgb__colsample_bytree=0.6197809453334862, xgb__learning_rate=0.05346846162736693, xgb__max_depth=6, xgb__min_child_weight=2, xgb__n_estimators=259, xgb__subsample=0.776446544535664; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.6197809453334862, xgb__learning_rate=0.05346846162736693, xgb__max_depth=6, xgb__min_child_weight=2, xgb__n_estimators=259, xgb__subsample=0.776446544535664; total time=   2.6s
# [CV] END xgb__colsample_bytree=0.6197809453334862, xgb__learning_rate=0.05346846162736693, xgb__max_depth=6, xgb__min_child_weight=2, xgb__n_estimators=259, xgb__subsample=0.776446544535664; total time=   1.8s
# [CV] END xgb__colsample_bytree=0.7963483619396967, xgb__learning_rate=0.03425599789981457, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=354, xgb__subsample=0.9015698781899479; total time=   2.3s
# [CV] END xgb__colsample_bytree=0.5599326836668415, xgb__learning_rate=0.11128455142108838, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=473, xgb__subsample=0.6093821097865351; total time=   7.1s
# [CV] END xgb__colsample_bytree=0.5599326836668415, xgb__learning_rate=0.11128455142108838, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=473, xgb__subsample=0.6093821097865351; total time=   7.9s
# [CV] END xgb__colsample_bytree=0.5599326836668415, xgb__learning_rate=0.11128455142108838, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=473, xgb__subsample=0.6093821097865351; total time=   7.6s
# [CV] END xgb__colsample_bytree=0.7963483619396967, xgb__learning_rate=0.03425599789981457, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=354, xgb__subsample=0.9015698781899479; total time=   2.7s
# [CV] END xgb__colsample_bytree=0.7963483619396967, xgb__learning_rate=0.03425599789981457, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=354, xgb__subsample=0.9015698781899479; total time=   2.8s
# [CV] END xgb__colsample_bytree=0.9883074779163264, xgb__learning_rate=0.1333111039954694, xgb__max_depth=9, xgb__min_child_weight=1, xgb__n_estimators=323, xgb__subsample=0.9541329429833268; total time=   6.3s
# [CV] END xgb__colsample_bytree=0.9883074779163264, xgb__learning_rate=0.1333111039954694, xgb__max_depth=9, xgb__min_child_weight=1, xgb__n_estimators=323, xgb__subsample=0.9541329429833268; total time=   6.8s
# [CV] END xgb__colsample_bytree=0.7351503172230192, xgb__learning_rate=0.3050269422684529, xgb__max_depth=8, xgb__min_child_weight=3, xgb__n_estimators=339, xgb__subsample=0.8991725624922755; total time=   3.8s
# [CV] END xgb__colsample_bytree=0.9883074779163264, xgb__learning_rate=0.1333111039954694, xgb__max_depth=9, xgb__min_child_weight=1, xgb__n_estimators=323, xgb__subsample=0.9541329429833268; total time=   6.9s
# [CV] END xgb__colsample_bytree=0.5753587719827147, xgb__learning_rate=0.1624596330222156, xgb__max_depth=7, xgb__min_child_weight=3, xgb__n_estimators=247, xgb__subsample=0.6629794526009424; total time=   2.8s
# [CV] END xgb__colsample_bytree=0.5753587719827147, xgb__learning_rate=0.1624596330222156, xgb__max_depth=7, xgb__min_child_weight=3, xgb__n_estimators=247, xgb__subsample=0.6629794526009424; total time=   2.8s
# [CV] END xgb__colsample_bytree=0.5753587719827147, xgb__learning_rate=0.1624596330222156, xgb__max_depth=7, xgb__min_child_weight=3, xgb__n_estimators=247, xgb__subsample=0.6629794526009424; total time=   2.4s
# [CV] END xgb__colsample_bytree=0.7351503172230192, xgb__learning_rate=0.3050269422684529, xgb__max_depth=8, xgb__min_child_weight=3, xgb__n_estimators=339, xgb__subsample=0.8991725624922755; total time=   4.0s
# [CV] END xgb__colsample_bytree=0.7351503172230192, xgb__learning_rate=0.3050269422684529, xgb__max_depth=8, xgb__min_child_weight=3, xgb__n_estimators=339, xgb__subsample=0.8991725624922755; total time=   4.5s
# [CV] END xgb__colsample_bytree=0.6101205237827741, xgb__learning_rate=0.22334485973140536, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=247, xgb__subsample=0.822586395204725; total time=   4.3s
# [CV] END xgb__colsample_bytree=0.8299920230170895, xgb__learning_rate=0.25516666006036476, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=159, xgb__subsample=0.6304145874152045; total time=   1.1s
# [CV] END xgb__colsample_bytree=0.6101205237827741, xgb__learning_rate=0.22334485973140536, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=247, xgb__subsample=0.822586395204725; total time=   4.3s
# [CV] END xgb__colsample_bytree=0.8299920230170895, xgb__learning_rate=0.25516666006036476, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=159, xgb__subsample=0.6304145874152045; total time=   0.9s
# [CV] END xgb__colsample_bytree=0.8299920230170895, xgb__learning_rate=0.25516666006036476, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=159, xgb__subsample=0.6304145874152045; total time=   1.1s
# [CV] END xgb__colsample_bytree=0.6101205237827741, xgb__learning_rate=0.22334485973140536, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=247, xgb__subsample=0.822586395204725; total time=   4.2s
# [CV] END xgb__colsample_bytree=0.6705331755251293, xgb__learning_rate=0.04404205637217672, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=397, xgb__subsample=0.6289708138575778; total time=   5.1s
# [CV] END xgb__colsample_bytree=0.6695148955243504, xgb__learning_rate=0.11476287238379826, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=251, xgb__subsample=0.702254063561095; total time=   2.0s
# [CV] END xgb__colsample_bytree=0.5871832145024958, xgb__learning_rate=0.21728132143073978, xgb__max_depth=9, xgb__min_child_weight=2, xgb__n_estimators=459, xgb__subsample=0.5687604720729966; total time=   6.7s
# [CV] END xgb__colsample_bytree=0.9981268498789622, xgb__learning_rate=0.2996258053866381, xgb__max_depth=7, xgb__min_child_weight=1, xgb__n_estimators=259, xgb__subsample=0.816550728636634; total time=   3.3s
# [CV] END xgb__colsample_bytree=0.6705331755251293, xgb__learning_rate=0.04404205637217672, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=397, xgb__subsample=0.6289708138575778; total time=   6.2s
# [CV] END xgb__colsample_bytree=0.9981268498789622, xgb__learning_rate=0.2996258053866381, xgb__max_depth=7, xgb__min_child_weight=1, xgb__n_estimators=259, xgb__subsample=0.816550728636634; total time=   3.3s
# [CV] END xgb__colsample_bytree=0.9981268498789622, xgb__learning_rate=0.2996258053866381, xgb__max_depth=7, xgb__min_child_weight=1, xgb__n_estimators=259, xgb__subsample=0.816550728636634; total time=   3.3s
# [CV] END xgb__colsample_bytree=0.6705331755251293, xgb__learning_rate=0.04404205637217672, xgb__max_depth=9, xgb__min_child_weight=3, xgb__n_estimators=397, xgb__subsample=0.6289708138575778; total time=   7.0s
# [CV] END xgb__colsample_bytree=0.6695148955243504, xgb__learning_rate=0.11476287238379826, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=251, xgb__subsample=0.702254063561095; total time=   1.6s
# [CV] END xgb__colsample_bytree=0.9438850493804799, xgb__learning_rate=0.2652785346302538, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=203, xgb__subsample=0.803214529829795; total time=   1.0s
# [CV] END xgb__colsample_bytree=0.6695148955243504, xgb__learning_rate=0.11476287238379826, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=251, xgb__subsample=0.702254063561095; total time=   1.8s
# [CV] END xgb__colsample_bytree=0.5871832145024958, xgb__learning_rate=0.21728132143073978, xgb__max_depth=9, xgb__min_child_weight=2, xgb__n_estimators=459, xgb__subsample=0.5687604720729966; total time=   8.0s
# [CV] END xgb__colsample_bytree=0.9438850493804799, xgb__learning_rate=0.2652785346302538, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=203, xgb__subsample=0.803214529829795; total time=   1.2s
# [CV] END xgb__colsample_bytree=0.9438850493804799, xgb__learning_rate=0.2652785346302538, xgb__max_depth=3, xgb__min_child_weight=4, xgb__n_estimators=203, xgb__subsample=0.803214529829795; total time=   1.2s
# [CV] END xgb__colsample_bytree=0.5871832145024958, xgb__learning_rate=0.21728132143073978, xgb__max_depth=9, xgb__min_child_weight=2, xgb__n_estimators=459, xgb__subsample=0.5687604720729966; total time=   8.5s
# [CV] END xgb__colsample_bytree=0.6526819301721967, xgb__learning_rate=0.15568412607586798, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=268, xgb__subsample=0.5879626263386727; total time=   1.7s
# [CV] END xgb__colsample_bytree=0.6526819301721967, xgb__learning_rate=0.15568412607586798, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=268, xgb__subsample=0.5879626263386727; total time=   1.9s
# [CV] END xgb__colsample_bytree=0.6526819301721967, xgb__learning_rate=0.15568412607586798, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=268, xgb__subsample=0.5879626263386727; total time=   2.1s
# [CV] END xgb__colsample_bytree=0.5045985258083148, xgb__learning_rate=0.04044146285980963, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=448, xgb__subsample=0.6419604873687328; total time=   3.3s
# [CV] END xgb__colsample_bytree=0.5045985258083148, xgb__learning_rate=0.04044146285980963, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=448, xgb__subsample=0.6419604873687328; total time=   3.2s
# [CV] END xgb__colsample_bytree=0.5045985258083148, xgb__learning_rate=0.04044146285980963, xgb__max_depth=5, xgb__min_child_weight=1, xgb__n_estimators=448, xgb__subsample=0.6419604873687328; total time=   3.6s
# [CV] END xgb__colsample_bytree=0.5090376818077604, xgb__learning_rate=0.15816811455503038, xgb__max_depth=6, xgb__min_child_weight=4, xgb__n_estimators=483, xgb__subsample=0.8720852615282811; total time=   3.6s
# [CV] END xgb__colsample_bytree=0.5090376818077604, xgb__learning_rate=0.15816811455503038, xgb__max_depth=6, xgb__min_child_weight=4, xgb__n_estimators=483, xgb__subsample=0.8720852615282811; total time=   3.9s
# [CV] END xgb__colsample_bytree=0.5090376818077604, xgb__learning_rate=0.15816811455503038, xgb__max_depth=6, xgb__min_child_weight=4, xgb__n_estimators=483, xgb__subsample=0.8720852615282811; total time=   3.9s
# [CV] END xgb__colsample_bytree=0.6252309093027921, xgb__learning_rate=0.18696125426816315, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=150, xgb__subsample=0.9460232775885566; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.8604699621260646, xgb__learning_rate=0.10241823755571676, xgb__max_depth=6, xgb__min_child_weight=3, xgb__n_estimators=470, xgb__subsample=0.8181663090929476; total time=   4.3s
# [CV] END xgb__colsample_bytree=0.6252309093027921, xgb__learning_rate=0.18696125426816315, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=150, xgb__subsample=0.9460232775885566; total time=   2.0s
# [CV] END xgb__colsample_bytree=0.6252309093027921, xgb__learning_rate=0.18696125426816315, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=150, xgb__subsample=0.9460232775885566; total time=   2.2s
# [CV] END xgb__colsample_bytree=0.8604699621260646, xgb__learning_rate=0.10241823755571676, xgb__max_depth=6, xgb__min_child_weight=3, xgb__n_estimators=470, xgb__subsample=0.8181663090929476; total time=   3.1s
# [CV] END xgb__colsample_bytree=0.8604699621260646, xgb__learning_rate=0.10241823755571676, xgb__max_depth=6, xgb__min_child_weight=3, xgb__n_estimators=470, xgb__subsample=0.8181663090929476; total time=   3.5s
# [CV] END xgb__colsample_bytree=0.9320837825359516, xgb__learning_rate=0.07905558047246658, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=134, xgb__subsample=0.8842770071531545; total time=   1.1s
# [CV] END xgb__colsample_bytree=0.9320837825359516, xgb__learning_rate=0.07905558047246658, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=134, xgb__subsample=0.8842770071531545; total time=   1.0s
# [CV] END xgb__colsample_bytree=0.9320837825359516, xgb__learning_rate=0.07905558047246658, xgb__max_depth=5, xgb__min_child_weight=4, xgb__n_estimators=134, xgb__subsample=0.8842770071531545; total time=   0.9s
# [CV] END xgb__colsample_bytree=0.8155693129986314, xgb__learning_rate=0.24844339106249452, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=383, xgb__subsample=0.8344620298315498; total time=   4.7s
# [CV] END xgb__colsample_bytree=0.8155693129986314, xgb__learning_rate=0.24844339106249452, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=383, xgb__subsample=0.8344620298315498; total time=   4.0s
# [CV] END xgb__colsample_bytree=0.8155693129986314, xgb__learning_rate=0.24844339106249452, xgb__max_depth=8, xgb__min_child_weight=1, xgb__n_estimators=383, xgb__subsample=0.8344620298315498; total time=   4.3s
#
# Tuning de XGBoost completado
#
# ✓ Tiempo: 0.8 minutos
#
# Mejores hiperparámetros encontrados:
#
#   xgb__colsample_bytree: 0.5826334695315012
#   xgb__learning_rate: 0.01469092202235818
#   xgb__max_depth: 3
#   xgb__min_child_weight: 4
#   xgb__n_estimators: 228
#   xgb__subsample: 0.5993578407670862
#
# Mejor MAE en CV: 11.183 días

# %%
# Evaluamos el modelo optimizado
model_xgb_opt = random_search_xgb.best_estimator_

val_preds_xgb_opt = model_xgb_opt.predict(x_val)
val_mae_xgb_opt = mean_absolute_error(y_val, val_preds_xgb_opt)
val_rmse_xgb_opt = root_mean_squared_error(y_val, val_preds_xgb_opt)

test_preds_xgb_opt = model_xgb_opt.predict(x_test)
test_mae_xgb_opt = mean_absolute_error(y_test, test_preds_xgb_opt)
test_rmse_xgb_opt = root_mean_squared_error(y_test, test_preds_xgb_opt)

print(f"""
{"=" * 70}
COMPARACIÓN – XGBoost baseline vs optimizado
{"=" * 70}

XGBOOST BASELINE
  Validación | MAE={val_mae_xgb:.3f} días | RMSE={val_rmse_xgb:.3f} días
  Test       | MAE={test_mae_xgb:.3f} días | RMSE={test_rmse_xgb:.3f} días

XGBOOST OPTIMIZADO
  Validación | MAE={val_mae_xgb_opt:.3f} días | RMSE={val_rmse_xgb_opt:.3f} días
  Test       | MAE={test_mae_xgb_opt:.3f} días | RMSE={test_rmse_xgb_opt:.3f} días

MEJORA
  Validación | {((val_mae_xgb - val_mae_xgb_opt) / val_mae_xgb * 100):+.2f}% (MAE)
  Test       | {((test_mae_xgb - test_mae_xgb_opt) / test_mae_xgb * 100):+.2f}% (MAE)
{"=" * 70}
""")
# Out:
# ======================================================================
# COMPARACIÓN – XGBoost baseline vs optimizado
# ======================================================================
#
# XGBOOST BASELINE
#   Validación | MAE=4.455 días | RMSE=6.015 días
#   Test       | MAE=3.851 días | RMSE=5.048 días
#
# XGBOOST OPTIMIZADO
#   Validación | MAE=5.452 días | RMSE=7.212 días
#   Test       | MAE=4.680 días | RMSE=5.904 días
#
# MEJORA
#   Validación | -22.40% (MAE)
#   Test       | -21.51% (MAE)
# ======================================================================

# %% [markdown]
# ### Conclusión: ¿Por qué empeora con tuning?
#
# El tuning de XGBoost **también empeoró** el modelo (4.680 días vs 3.851 días en test, **-11.96%**). Este patrón es similar al de Random Forest:
#
# **Raíz del problema:** la búsqueda de hiperparámetros encontró una combinación subóptima de parámetros:
# - Posiblemente una tasa de aprendizaje (`learning_rate`) demasiado baja
# - O una combinación de `max_depth`, `subsample` y `colsample_bytree` que limita la capacidad del modelo
# - Resultado: el modelo no logra capturar todos los patrones de los datos
#
# **¿Por qué pasó esto?**
# - Los parámetros por defecto de XGBoost ya están bien calibrados para problemas de regresión
# - El espacio de búsqueda era amplio e incluía combinaciones que funcionan peor
# - La búsqueda aleatoria no garantiza encontrar el óptimo global
#
# **Patrón general descubierto:**
# - Los parámetros por defecto de ambos algoritmos (RF y XGBoost) ya incorporan **configuraciones sensatas** para la mayoría de problemas
# - Cuando el baseline funciona bien, el tuning puede encontrar configuraciones peores en lugar de mejores
# - La búsqueda aleatoria explora el espacio de forma incompleta y puede perderse los buenos valores
#
# **Conclusión provisional:** hasta este punto, **XGBoost baseline con parámetros por defecto es el mejor modelo**, con MAE de 3.851 días en test. Tomamos este resultado como referencia para probar otros boosters.
#
# ## Más boosting con LightGBM
#
# LightGBM es otro algoritmo de gradient boosting ampliamente usado en tabulares por su esquema de histogramas y crecimiento leaf-wise. Tiende a entrenar muy rápido incluso con muchas columnas _one-hot_, así que lo probamos como alternativa adicional al pipeline con XGBoost.
#
# ### Modelo baseline de LightGBM

# %%
# Pipeline con LightGBM
model_lgbm = Pipeline(
    [
        ("preprocess", preprocess),
        ("regressor", LGBMRegressor(random_state=42, verbose=-1)),
    ]
)

start_time = time.time()
model_lgbm.fit(x_train, y_train)
elapsed_time = time.time() - start_time

# Predicciones
val_preds_lgbm = model_lgbm.predict(x_val)
test_preds_lgbm = model_lgbm.predict(x_test)

# Métricas
mae_val_lgbm = mean_absolute_error(y_val, val_preds_lgbm)
rmse_val_lgbm = root_mean_squared_error(y_val, val_preds_lgbm)
mae_test_lgbm = mean_absolute_error(y_test, test_preds_lgbm)
rmse_test_lgbm = root_mean_squared_error(y_test, test_preds_lgbm)

print(f"""
Resultados LightGBM Baseline:
  Tiempo de entrenamiento: {elapsed_time:.2f} segundos

  Conjunto de Validación:
    MAE:  {mae_val_lgbm:.3f} días
    RMSE: {rmse_val_lgbm:.3f} días

  Conjunto de Prueba:
    MAE:  {mae_test_lgbm:.3f} días
    RMSE: {rmse_test_lgbm:.3f} días

  Sesgo (error promedio): {(y_test - test_preds_lgbm).mean():.3f} días
""")
# Out:
# Resultados LightGBM Baseline:
#   Tiempo de entrenamiento: 0.82 segundos
#
#   Conjunto de Validación:
#     MAE:  4.484 días
#     RMSE: 6.369 días
#
#   Conjunto de Prueba:
#     MAE:  3.904 días
#     RMSE: 5.048 días
#
#   Sesgo (error promedio): -2.121 días
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# El baseline de LightGBM sirve como control rápido para saber si los histogramas y el crecimiento orientado a hojas capturan los mismos patrones geográficos identificados por XGBoost.
#
# ### Ajuste de hiperparámetros de LightGBM

# %%
# Distribuciones de parámetros para LightGBM
param_distributions_lgbm = {
    "regressor__n_estimators": randint(100, 500),
    "regressor__max_depth": randint(3, 15),
    "regressor__learning_rate": uniform(0.01, 0.3),
    "regressor__num_leaves": randint(20, 150),
    "regressor__subsample": uniform(0.6, 0.4),
    "regressor__colsample_bytree": uniform(0.6, 0.4),
    "regressor__min_child_samples": randint(5, 50),
}

# Búsqueda aleatoria
random_search_lgbm = RandomizedSearchCV(
    estimator=model_lgbm,
    param_distributions=param_distributions_lgbm,
    n_iter=50,
    cv=5,
    scoring="neg_mean_absolute_error",
    random_state=42,
    n_jobs=-1,
    verbose=1,
)

start_time = time.time()
random_search_lgbm.fit(x_train, y_train)
elapsed_time = time.time() - start_time

print(f"""
Ajuste de Hiperparámetros LightGBM:
  Tiempo de entrenamiento: {elapsed_time:.2f} segundos
  Mejor MAE (CV): {-random_search_lgbm.best_score_:.3f} días

  Mejores parámetros:
""")
for param, value in random_search_lgbm.best_params_.items():
    print(f"    {param}: {value}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Ajuste de Hiperparámetros LightGBM:
#   Tiempo de entrenamiento: 598.30 segundos
#   Mejor MAE (CV): 8.297 días
#
#   Mejores parámetros:
#
#     regressor__colsample_bytree: 0.9400154311159197
#     regressor__learning_rate: 0.14483520224146101
#     regressor__max_depth: 3
#     regressor__min_child_samples: 27
#     regressor__n_estimators: 161
#     regressor__num_leaves: 56
#     regressor__subsample: 0.8918424713352255

# %%
# Evaluación del modelo optimizado
model_lgbm_opt = random_search_lgbm.best_estimator_

val_preds_lgbm_opt = model_lgbm_opt.predict(x_val)
test_preds_lgbm_opt = model_lgbm_opt.predict(x_test)

mae_val_lgbm_opt = mean_absolute_error(y_val, val_preds_lgbm_opt)
rmse_val_lgbm_opt = root_mean_squared_error(y_val, val_preds_lgbm_opt)
mae_test_lgbm_opt = mean_absolute_error(y_test, test_preds_lgbm_opt)
rmse_test_lgbm_opt = root_mean_squared_error(y_test, test_preds_lgbm_opt)

print(f"""
Resultados LightGBM Optimizado:
  Conjunto de Validación:
    MAE:  {mae_val_lgbm_opt:.3f} días
    RMSE: {rmse_val_lgbm_opt:.3f} días

  Conjunto de Prueba:
    MAE:  {mae_test_lgbm_opt:.3f} días
    RMSE: {rmse_test_lgbm_opt:.3f} días

  Sesgo (error promedio): {(y_test - test_preds_lgbm_opt).mean():.3f} días

  Mejora sobre baseline: {((mae_test_lgbm - mae_test_lgbm_opt) / mae_test_lgbm * 100):.2f}%
""")
# Out:
# Resultados LightGBM Optimizado:
#   Conjunto de Validación:
#     MAE:  4.536 días
#     RMSE: 6.194 días
#
#   Conjunto de Prueba:
#     MAE:  3.933 días
#     RMSE: 5.153 días
#
#   Sesgo (error promedio): -2.014 días
#
#   Mejora sobre baseline: -0.74%
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/datwaft/Developer/Education/aprendizaje_automatico/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Con esto confirmamos si LightGBM gana algo afinando `num_leaves`, `learning_rate` y muestreos columna/fila. El reporte anterior deja a la vista cualquier mejora porcentual frente a su baseline.
#
# En esta corrida, LightGBM baseline quedó muy cerca del desempeño de XGBoost (MAE test = 3.904 días, RMSE = 5.048 días), pero no lo superó. El _random search_ probó distintas combinaciones y terminó con un modelo ligeramente peor (MAE = 3.933, RMSE = 5.153; -0.74% vs baseline), por lo que lo mantenemos como una alternativa rápida pero no como el mejor modelo.
#
# ## Boosting específico para variables categóricas con CatBoost
#
# CatBoost implementa boosting orientado a manejar categorías sin codificación manual. En nuestro pipeline mantenemos el `ColumnTransformer` para reutilizar el mismo flujo, pero CatBoost aporta regularizaciones distintas (ordenamiento, _oblivious trees_) que vale la pena comparar.
#
# ### Modelo baseline de CatBoost

# %%
# Pipeline con CatBoost
model_catboost = Pipeline(
    [
        ("preprocess", preprocess),
        ("regressor", CatBoostRegressor(random_state=42, verbose=0)),
    ]
)

start_time = time.time()
model_catboost.fit(x_train, y_train)
elapsed_time = time.time() - start_time

# Predicciones
val_preds_cb = model_catboost.predict(x_val)
test_preds_cb = model_catboost.predict(x_test)

# Métricas
mae_val_cb = mean_absolute_error(y_val, val_preds_cb)
rmse_val_cb = root_mean_squared_error(y_val, val_preds_cb)
mae_test_cb = mean_absolute_error(y_test, test_preds_cb)
rmse_test_cb = root_mean_squared_error(y_test, test_preds_cb)

print(f"""
Resultados CatBoost Baseline:
  Tiempo de entrenamiento: {elapsed_time:.2f} segundos

  Conjunto de Validación:
    MAE:  {mae_val_cb:.3f} días
    RMSE: {rmse_val_cb:.3f} días

  Conjunto de Prueba:
    MAE:  {mae_test_cb:.3f} días
    RMSE: {rmse_test_cb:.3f} días

  Sesgo (error promedio): {(y_test - test_preds_cb).mean():.3f} días
""")
# Out:
# Resultados CatBoost Baseline:
#   Tiempo de entrenamiento: 3.94 segundos
#
#   Conjunto de Validación:
#     MAE:  4.216 días
#     RMSE: 5.644 días
#
#   Conjunto de Prueba:
#     MAE:  3.710 días
#     RMSE: 4.772 días
#
#   Sesgo (error promedio): -1.965 días

# %% [markdown]
# ### Ajuste de hiperparámetros de CatBoost

# %%
# Distribuciones de parámetros para CatBoost
param_distributions_cb = {
    "regressor__iterations": randint(100, 500),
    "regressor__depth": randint(4, 10),
    "regressor__learning_rate": uniform(0.01, 0.3),
    "regressor__l2_leaf_reg": uniform(1, 10),
    "regressor__subsample": uniform(0.6, 0.4),
    "regressor__min_data_in_leaf": randint(1, 50),
}

# Búsqueda aleatoria
random_search_cb = RandomizedSearchCV(
    estimator=model_catboost,
    param_distributions=param_distributions_cb,
    n_iter=50,
    cv=5,
    scoring="neg_mean_absolute_error",
    random_state=42,
    n_jobs=-1,
    verbose=1,
)

start_time = time.time()
random_search_cb.fit(x_train, y_train)
elapsed_time = time.time() - start_time

print(f"""
Ajuste de Hiperparámetros CatBoost:
  Tiempo de entrenamiento: {elapsed_time:.2f} segundos
  Mejor MAE (CV): {-random_search_cb.best_score_:.3f} días

  Mejores parámetros:
""")
for param, value in random_search_cb.best_params_.items():
    print(f"    {param}: {value}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
#
# Ajuste de Hiperparámetros CatBoost:
#   Tiempo de entrenamiento: 164.11 segundos
#   Mejor MAE (CV): 7.811 días
#
#   Mejores parámetros:
#
#     regressor__depth: 4
#     regressor__iterations: 476
#     regressor__l2_leaf_reg: 7.476901205413624
#     regressor__learning_rate: 0.010156113098594747
#     regressor__min_data_in_leaf: 13
#     regressor__subsample: 0.9442922333025374

# %%
# Evaluación del modelo optimizado
model_catboost_opt = random_search_cb.best_estimator_

val_preds_cb_opt = model_catboost_opt.predict(x_val)
test_preds_cb_opt = model_catboost_opt.predict(x_test)

mae_val_cb_opt = mean_absolute_error(y_val, val_preds_cb_opt)
rmse_val_cb_opt = root_mean_squared_error(y_val, val_preds_cb_opt)
mae_test_cb_opt = mean_absolute_error(y_test, test_preds_cb_opt)
rmse_test_cb_opt = root_mean_squared_error(y_test, test_preds_cb_opt)

print(f"""
Resultados CatBoost Optimizado:
  Conjunto de Validación:
    MAE:  {mae_val_cb_opt:.3f} días
    RMSE: {rmse_val_cb_opt:.3f} días

  Conjunto de Prueba:
    MAE:  {mae_test_cb_opt:.3f} días
    RMSE: {rmse_test_cb_opt:.3f} días

  Sesgo (error promedio): {(y_test - test_preds_cb_opt).mean():.3f} días

  Mejora sobre baseline: {((mae_test_cb - mae_test_cb_opt) / mae_test_cb * 100):.2f}%
""")
# Out:
# Resultados CatBoost Optimizado:
#   Conjunto de Validación:
#     MAE:  5.053 días
#     RMSE: 6.526 días
#
#   Conjunto de Prueba:
#     MAE:  4.491 días
#     RMSE: 5.740 días
#
#   Sesgo (error promedio): -2.751 días
#
#   Mejora sobre baseline: -21.04%

# %% [markdown]
# CatBoost nos da otra perspectiva sobre boosting, especialmente si la codificación _one-hot_ limita la información de las categorías. Al igual que con LightGBM, reportamos las mejoras para documentar si vale la pena la complejidad extra.
#
# Los resultados muestran que **CatBoost baseline es el mejor modelo hasta ahora**: alcanzó MAE de 3.710 días y RMSE de 4.772 días, superando a XGBoost baseline por ~3.7% y manteniendo un sesgo moderado (-1.965 días). El intento de tuning lo empeoró notablemente (MAE = 4.491, RMSE = 5.740; -21.04%), así que nos quedamos con la configuración por defecto como referencia principal.
#
# ## Conclusiones
#
# ### Resumen de modelos evaluados

# %%
mae_by_model = {
    "Random Forest Baseline": test_mae,
    "Random Forest Optimizado": test_mae_opt,
    "XGBoost Baseline": test_mae_xgb,
    "XGBoost Optimizado": test_mae_xgb_opt,
    "LightGBM Baseline": mae_test_lgbm,
    "LightGBM Optimizado": mae_test_lgbm_opt,
    "CatBoost Baseline": mae_test_cb,
    "CatBoost Optimizado": mae_test_cb_opt,
}

rmse_by_model = {
    "Random Forest Baseline": test_rmse,
    "Random Forest Optimizado": test_rmse_opt,
    "XGBoost Baseline": test_rmse_xgb,
    "XGBoost Optimizado": test_rmse_xgb_opt,
    "LightGBM Baseline": rmse_test_lgbm,
    "LightGBM Optimizado": rmse_test_lgbm_opt,
    "CatBoost Baseline": rmse_test_cb,
    "CatBoost Optimizado": rmse_test_cb_opt,
}

best_model_name = min(mae_by_model, key=lambda model_name: mae_by_model[model_name])
best_mae = mae_by_model[best_model_name]
best_rmse = rmse_by_model[best_model_name]

print(f"""
{"=" * 70}
RESUMEN FINAL DE MODELOS
{"=" * 70}

Modelo                          Test MAE    Test RMSE   vs RF Baseline
----------------------------------------------------------------------
Random Forest Baseline          {test_mae:.3f}      {test_rmse:.3f}      (baseline)
Random Forest Optimizado        {test_mae_opt:.3f}      {test_rmse_opt:.3f}      {((test_mae - test_mae_opt) / test_mae * 100):+.2f}%
XGBoost Baseline                {test_mae_xgb:.3f}      {test_rmse_xgb:.3f}      {((test_mae - test_mae_xgb) / test_mae * 100):+.2f}%
XGBoost Optimizado              {test_mae_xgb_opt:.3f}      {test_rmse_xgb_opt:.3f}      {((test_mae - test_mae_xgb_opt) / test_mae * 100):+.2f}%
LightGBM Baseline               {mae_test_lgbm:.3f}      {rmse_test_lgbm:.3f}      {((test_mae - mae_test_lgbm) / test_mae * 100):+.2f}%
LightGBM Optimizado             {mae_test_lgbm_opt:.3f}      {rmse_test_lgbm_opt:.3f}      {((test_mae - mae_test_lgbm_opt) / test_mae * 100):+.2f}%
CatBoost Baseline               {mae_test_cb:.3f}      {rmse_test_cb:.3f}      {((test_mae - mae_test_cb) / test_mae * 100):+.2f}%
CatBoost Optimizado             {mae_test_cb_opt:.3f}      {rmse_test_cb_opt:.3f}      {((test_mae - mae_test_cb_opt) / test_mae * 100):+.2f}%
{"=" * 70}

MEJOR MODELO: {best_model_name} (MAE = {best_mae:.3f} días | RMSE = {best_rmse:.3f} días)
""")
# Out:
# ======================================================================
# RESUMEN FINAL DE MODELOS
# ======================================================================
#
# Modelo                          Test MAE    Test RMSE   vs RF Baseline
# ----------------------------------------------------------------------
# Random Forest Baseline          4.180      5.545      (baseline)
# Random Forest Optimizado        4.625      5.901      -10.64%
# XGBoost Baseline                3.851      5.048      +7.86%
# XGBoost Optimizado              4.680      5.904      -11.96%
# LightGBM Baseline               3.904      5.048      +6.60%
# LightGBM Optimizado             3.933      5.153      +5.91%
# CatBoost Baseline               3.710      4.772      +11.24%
# CatBoost Optimizado             4.491      5.740      -7.44%
# ======================================================================
#
# MEJOR MODELO: CatBoost Baseline (MAE = 3.710 días | RMSE = 4.772 días)

# %% [markdown]
# ### Hallazgos principales
#
# 1. **La distancia geográfica es el predictor más fuerte** (correlación 0.394 con tiempo de entrega). Esto confirma la intuición de que la logística en Brasil está dominada por las grandes distancias del país.
#
# 2. **La ubicación del cliente tiene impacto dramático:**
#    - Estados remotos del norte (RR, AP, AM): 26-29 días promedio
#    - Estados del sureste (SP, MG, RJ): 8-13 días promedio
#    - Diferencia de hasta **3x** entre regiones
#
# 3. **Los patrones temporales tienen impacto marginal:** comprar en fin de semana o fuera de horario laboral añade menos de 0.5 días en promedio. La logística de Olist es consistente independientemente del momento de compra.
#
# 4. **XGBoost supera a Random Forest** en 7.86% (MAE 3.851 vs 4.180 días), confirmando que el boosting captura mejor los patrones complejos de este problema.
#
# 5. **El tuning de hiperparámetros empeoró ambos modelos.** Los parámetros por defecto de RF y XGBoost ya están bien calibrados. La búsqueda aleatoria encontró configuraciones que regularizaban demasiado o limitaban la capacidad del modelo, causando peor desempeño.
# 6. **LightGBM queda cerca y CatBoost lidera.** LightGBM baseline (MAE 3.904) ofrece resultados muy similares a XGBoost, pero CatBoost baseline es el que finalmente domina la tabla (MAE 3.710 | RMSE 4.772), mejorando ~3.7% sobre el benchmark de XGBoost.
#
# ### Modelo final recomendado
#
# Basándonos en los resultados más recientes, **CatBoost Baseline es el mejor modelo** con MAE de 3.710 días y RMSE de 4.772 días. La tabla-resumen de la sección anterior deja visibles las métricas de todos los modelos para corroborar esta conclusión.
#
# ### Implicaciones de negocio
#
# 1. **Precisión razonable para comunicación al cliente:** un error de ~4 días es aceptable para dar estimaciones de entrega, especialmente si se comunica como rango (ej. "llegará entre 10-14 días").
#
# 2. **Oportunidades de mejora logística:** los estados del norte (AM, RR, AP) tienen tiempos 2-3x mayores. Inversión en infraestructura logística en estas regiones tendría alto impacto.
#
# 3. **El modelo es conservador:** el sesgo negativo (-2 días) significa que el modelo tiende a predecir entregas más lentas de lo real. Esto es preferible comercialmente a prometer entregas rápidas y no cumplir.
#
# ### Limitaciones y trabajo futuro
#
# 1. **Sesgo sistemático:** el modelo aún sobreestima ~2 días. Técnicas de calibración podrían reducir este sesgo.
#
# 2. **Features no disponibles:** el modelo no tiene acceso a:
#    - Disponibilidad de stock del vendedor
#    - Capacidad de la red logística en tiempo real
#    - Condiciones climáticas o eventos especiales
#
# 3. **Posibles mejoras:**
#    - Modelos específicos por región (un modelo para el norte, otro para el sureste)
#    - Incorporar datos externos (feriados, clima, huelgas de transporte)
#    - Análisis de errores por segmento para identificar casos difíciles
